# %% [markdown]
# # Code implementation exploration
# This Notebook has been created with the goal to explore the way the code implementation of stable-baselines and openai actually work, based on small "dummy"-cases.
#
#
# 1. Environment
# 2. Agent framework

# %% [markdown]
# ## 1. Environment

# %%
import numpy as np
import pandas as pd
import gym
from gym import error, spaces, utils
from stable_baselines3.common.vec_env import DummyVecEnv
# Out:
# (config) no crisis measure selected.

# %%
from environment.FinancialMarketEnv import FinancialMarketEnv
from config.config import *
from setup_functions import *

# %%
# import dummy data
dumdat = pd.read_csv("data/preprocessed/old/done_data.csv", index_col=0)
dumdat = dumdat[["datadate", "tic", "adjcp"]]
dumdat.index = dumdat["datadate"].factorize()[0]
dumdat
# Out:
#       datadate   tic       adjcp
# 0     20090102  AAPL   12.964286
# 0     20090102   AXP   19.330000
# 0     20090102    BA   45.250000
# 0     20090102   CAT   46.910000
# 0     20090102  CSCO   16.960000
# ...        ...   ...         ...
# 2925  20200817     V  199.430000
# 2925  20200817    VZ   58.780000
# 2925  20200817   WBA   41.175000
# 2925  20200817   WMT  135.600000
# 2925  20200817   XOM   42.640000
#
# [87780 rows x 3 columns]

# %%
#dumdat = dumdat.loc[dumdat["tic"].isin(["AAPL", "AXP"])]
#dumdat.tic.unique()

# %%
# only pick 1 stock
dumdat = dumdat.loc[dumdat["tic"].isin(["AAPL"])]
# reduce data set to 5 days (4 possible steps)
#episode_length_steps = 5 
#dumdat = dumdat.loc[1-1:episode_length_steps-1]
#print("number of possible steps: ", len(dumdat.index.unique())-1)
dumdat.head(5)
# Out:
#    datadate   tic      adjcp
# 0  20090102  AAPL  12.964286
# 1  20090105  AAPL  13.511429
# 2  20090106  AAPL  13.288571
# 3  20090107  AAPL  13.001429
# 4  20090108  AAPL  13.242857

# %%
dumdat.tail(5)
# Out:
#       datadate   tic   adjcp
# 2921  20200811  AAPL  437.50
# 2922  20200812  AAPL  452.04
# 2923  20200813  AAPL  460.04
# 2924  20200814  AAPL  459.63
# 2925  20200817  AAPL  458.43

# %%
dumdat = dumdat.sort_values(["datadate", "tic"])
dumdat.index = dumdat["datadate"].factorize()[0]
dumdat
# Out:
#       datadate   tic       adjcp
# 0     20090102  AAPL   12.964286
# 1     20090105  AAPL   13.511429
# 2     20090106  AAPL   13.288571
# 3     20090107  AAPL   13.001429
# 4     20090108  AAPL   13.242857
# ...        ...   ...         ...
# 2921  20200811  AAPL  437.500000
# 2922  20200812  AAPL  452.040000
# 2923  20200813  AAPL  460.040000
# 2924  20200814  AAPL  459.630000
# 2925  20200817  AAPL  458.430000
#
# [2926 rows x 3 columns]

# %%
dum_train = dumdat[dumdat.index<=2000]
dum_test = dumdat[dumdat.index>2000]

# %%
dum_train.tic.unique()
# Out:
# array(['AAPL'], dtype=object)

# %%
env_train = FinancialMarketEnv(df=dum_train, 
                               features_list=["adjcp"],
                               day=0,
                               iteration=1,  # only used for logging.infoing
                                                          model_name="ppo",
                                                          # only used for logging.info
                                                          mode="train",
                                                          crisis_measure=None,
                                                          crisis_threshold=None,
                                                          hmax_normalize=100,
                                                          initial_cash_balance=1000000,
                                                          transaction_fee_percent=0.001,
                                                          reward_scaling=1e-4,
                                                          assets_dim=1,
                                                          shape_observation_space=1+1+1,
                                                          initial=True, # for validation, we always have an "initial state"
                                                          previous_state=[],
                                                          previous_asset_price=None,
                                                          price_colname="adjcp",
                                                          results_dir="dummyresults",
                                                          reset_counter=0)
# Out:
# {'cash': [1000000], 'n_asset_holdings': [0], 'adjcp': [12.964285714285714]}
# <class 'dict'>

# %%
vecenv_train = DummyVecEnv([lambda: FinancialMarketEnv(df=dum_train,  # was StockEnvTrain
                                                          features_list=["adjcp"],
                                                          day=0,
                                                          iteration=1,  # only used for logging.infoing
                                                          model_name="ppo",
                                                          # only used for logging.info
                                                          mode="train",
                                                          crisis_measure=None,
                                                          crisis_threshold=None,
                                                          hmax_normalize=100,
                                                          initial_cash_balance=1000000,
                                                          transaction_fee_percent=0.001,
                                                          reward_scaling=1e-4,
                                                          assets_dim=1,
                                                          shape_observation_space=1+1+1, # cash, price*stocks, n_holdings*stocks
                                                          initial=True, # for validation, we always have an "initial state"
                                                          previous_state=[],
                                                          previous_asset_price=None,
                                                          price_colname="adjcp",
                                                          results_dir="dummyresults",
                                                          reset_counter=0)])
# Out:
# {'cash': [1000000], 'n_asset_holdings': [0], 'adjcp': [12.964285714285714]}
# <class 'dict'>
# shapes:  {None: (3,)}
# self.keys:  [None]

# %%
vecenv_train.reset()
# Out:
# WARNING:root:(train) reset_env, initial = True, day = 0
# [1.00000000e+06 0.00000000e+00 1.29642857e+01]
# key:  None
# obs:  [1.00000000e+06 0.00000000e+00 1.29642857e+01]
# 1. elem of obs:  1000000.0
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[0., 0., 0.]], dtype=float32))])
# buf_obs[None]:  [[0. 0. 0.]]
# buf_obs[None][env_idx]:  [0. 0. 0.]
# a
# array([[1.0000000e+06, 0.0000000e+00, 1.2964286e+01]], dtype=float32)

# %%
results_dir, trained_dir = create_dirs(mode="run_dir", dummydata=True)
print(results_dir, trained_dir)
# Out:
# dummyresults\results\06-23-2021_04-14-35_ppo__fm1_st dummyresults\trained_models\06-23-2021_04-14-35_ppo__rew_addPFVal_fm1_st

# %%
logsave_path = os.path.join(results_dir, "_LOGGINGS")
os.makedirs(logsave_path)
print(logsave_path)
# Out:
# dummyresults\results\06-23-2021_04-14-35_ppo__fm1_st\_LOGGINGS

# %%
config_logging_to_txt(results_dir, trained_dir, logsave_path=logsave_path)

# %%
logging.basicConfig(filename=os.path.join(logsave_path, "run_log"),
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    # asctime = time, msecs, name = name of who runned it (?), levelname (e.g. DEBUG, INFO => verbosity), message
                    datefmt='%H:%M:%S',
                    #level=logging.INFO
                    #level=logging.DEBUG
                    level=logging.NOTSET)

# %%
env_train.seed(11)
env_train.action_space.seed(11)
# Out:
# [11]

# %%
model = PPO(policy='MlpPolicy',  # was PPO2 in sb2 tf1.x
            env=vecenv_train,  # environment where the agent learns and acts
            seed=11,

            ent_coef=agent_params._ppo.ENT_COEF,  # entropy coefficient # TODO: !!!
            # default parameters (unchanged from default as given by stable-baselines)
            learning_rate=agent_params._ppo.LEARNING_RATE,  # can also be variable, e.g. a function of the current progress remaining etc.
            # todo: where is learning rate used exactly?
            # nminibatches=8, # todo: was in old paper
            n_steps=agent_params._ppo.N_STEPS,
            n_epochs=agent_params._ppo.N_EPOCHS, #todo: surrogate loss?
            gamma=agent_params._ppo.GAMMA, # todo: would taking an actual interest rate make sense?
            gae_lambda=agent_params._ppo.GAE_LAMBDA, # todo: ?
            clip_range=agent_params._ppo.CLIP_RANGE,
            clip_range_vf=agent_params._ppo.CLIP_RANGE_VF, # todo: ?
            vf_coef=agent_params._ppo.VF_COEF,
            max_grad_norm=agent_params._ppo.MAX_GRAD_NORM,
            use_sde=agent_params._ppo.USE_SDE, # todo: ?
            sde_sample_freq=agent_params._ppo.SDE_SAMPLE_FREQ,
            target_kl=agent_params._ppo.TARGET_KL,
            tensorboard_log=agent_params._ppo.TENSORBOARD_LOG,
            create_eval_env=agent_params._ppo.CREATE_EVAL_ENV,
            policy_kwargs=agent_params._ppo.POLICY_KWARGS,
            verbose=agent_params._ppo.VERBOSE,
            device=agent_params._ppo.DEVICE,
            _init_setup_model=agent_params._ppo.INIT_SETUP_MODEL)
# Out:
# WARNING:root:-> stable_baselines3/common/utils.py : get_device()
# WARNING:root:-> stable_baselines3/common/on_policy_algorithm.py : _setup_model()
# WARNING:root:-> stable_baselines3/common/base_class.py : _setup_lr_schedule()
# WARNING:root:-> stable_baselines3/common/utils.py : get_schedule_fn()
# WARNING:root:-> stable_baselines3/common/utils.py : constant_fn()
# WARNING:root:-> stable_baselines3/common/base_class.py: set_random_seed()
# WARNING:root:-> stable_baselines3/common/utils.py : set_random_seed()
# WARNING:root:seeding rng of python, numpy, pytorch (for devices: CPU, GPU, CUDA)
# WARNING:root:seeding action space, seed : 11
# WARNING:root:-> stable_baselines3/common/utils.py : get_device()
# WARNING:root:-> stable_baselines3/common/utils.py : get_device()
# WARNING:root:-> stable_baselines3/common/utils.py : get_schedule_fn()
# WARNING:root:-> stable_baselines3/common/utils.py : constant_fn()

# %%
model.learn(total_timesteps= 100000)
# Out:
# WARNING:root:calling learn() in ppo.py
# WARNING:root:returning PPO class parameters
# WARNING:root:(train) reset_env, initial = True, day = 0
# WARNING:root:-> stable_baselines3/common/utils.py : configure_logger()
# WARNING:root:-> stable_baselines3/common/on_policy_algorithm.py : learn()
# WARNING:root:num_timesteps: 0, total_timesteps: 100000
# WARNING:root:collecting rollouts using the env.
# WARNING:root:-> stable_baselines3/common/on_policy_algorithm.py : collect_rollouts()
# WARNING:root:-> stable_baselines3/common/on_policy_algorithm.py : collect_rollouts()step 0/2048
# WARNING:root:env.step(clipped_actions)
# WARNING:root:n_rollout_steps : 2048
# [1.00000000e+06 0.00000000e+00 1.29642857e+01]
# key:  None
# obs:  [1.00000000e+06 0.00000000e+00 1.29642857e+01]
# 1. elem of obs:  1000000.0
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0000000e+06, 0.0000000e+00, 1.2964286e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0000000e+06 0.0000000e+00 1.2964286e+01]]
# buf_obs[None][env_idx]:  [1.0000000e+06 0.0000000e+00 1.2964286e+01]
# a
# key:  None
# obs:  [9.98702275e+05 1.00000000e+02 1.35114286e+01]
# 1. elem of obs:  998702.275
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0000000e+06, 0.0000000e+00, 1.2964286e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0000000e+06 0.0000000e+00 1.2964286e+01]]
# buf_obs[None][env_idx]:  [1.0000000e+06 0.0000000e+00 1.2964286e+01]
# a
# key:  None
# obs:  [9.98188327e+05 1.38000000e+02 1.32885714e+01]
# 1. elem of obs:  998188.32728
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9870225e+05, 1.0000000e+02, 1.3511429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9870225e+05 1.0000000e+02 1.3511429e+01]]
# buf_obs[None][env_idx]:  [9.9870225e+05 1.0000000e+02 1.3511429e+01]
# a
# key:  None
# obs:  [9.98135120e+05 1.42000000e+02 1.30014286e+01]
# 1. elem of obs:  998135.1198399999
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9818831e+05, 1.3800000e+02, 1.3288571e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9818831e+05 1.3800000e+02 1.3288571e+01]]
# buf_obs[None][env_idx]:  [9.9818831e+05 1.3800000e+02 1.3288571e+01]
# a
# key:  None
# obs:  [9.97106980e+05 2.21000000e+02 1.32428571e+01]
# 1. elem of obs:  997106.9798699999
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9813512e+05, 1.4200000e+02, 1.3001429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9813512e+05 1.4200000e+02 1.3001429e+01]]
# buf_obs[None][env_idx]:  [9.9813512e+05 1.4200000e+02 1.3001429e+01]
# a
# key:  None
# obs:  [9.97490639e+05 1.92000000e+02 1.29400000e+01]
# 1. elem of obs:  997490.6386842857
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9710700e+05, 2.2100000e+02, 1.3242857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9710700e+05 2.2100000e+02 1.3242857e+01]]
# buf_obs[None][env_idx]:  [9.9710700e+05 2.2100000e+02 1.3242857e+01]
# a
# key:  None
# obs:  [9.98162846e+05 1.40000000e+02 1.26657143e+01]
# 1. elem of obs:  998162.8458042857
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.974906e+05, 1.920000e+02, 1.294000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.974906e+05 1.920000e+02 1.294000e+01]]
# buf_obs[None][env_idx]:  [9.974906e+05 1.920000e+02 1.294000e+01]
# a
# key:  None
# obs:  [9.96895008e+05 2.40000000e+02 1.25300000e+01]
# 1. elem of obs:  996895.0078042857
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9816288e+05, 1.4000000e+02, 1.2665714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9816288e+05 1.4000000e+02 1.2665714e+01]]
# buf_obs[None][env_idx]:  [9.9816288e+05 1.4000000e+02 1.2665714e+01]
# a
# key:  None
# obs:  [9.95640755e+05 3.40000000e+02 1.21900000e+01]
# 1. elem of obs:  995640.7548042857
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.96895e+05, 2.40000e+02, 1.25300e+01]], dtype=float32))])
# buf_obs[None]:  [[9.96895e+05 2.40000e+02 1.25300e+01]]
# buf_obs[None][env_idx]:  [9.96895e+05 2.40000e+02 1.25300e+01]
# a
# key:  None
# obs:  [9.96858536e+05 2.40000000e+02 1.19114286e+01]
# 1. elem of obs:  996858.5358042857
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9564075e+05, 3.4000000e+02, 1.2190000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9564075e+05 3.4000000e+02 1.2190000e+01]]
# buf_obs[None][env_idx]:  [9.9564075e+05 3.4000000e+02 1.2190000e+01]
# a
# key:  None
# obs:  [9.97001330e+05 2.28000000e+02 1.17614286e+01]
# 1. elem of obs:  997001.3300099999
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9685856e+05, 2.4000000e+02, 1.1911428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9685856e+05 2.4000000e+02 1.1911428e+01]]
# buf_obs[None][env_idx]:  [9.9685856e+05 2.4000000e+02 1.1911428e+01]
# a
# key:  None
# obs:  [9.97142326e+05 2.16000000e+02 1.11714286e+01]
# 1. elem of obs:  997142.3260157142
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9700131e+05, 2.2800000e+02, 1.1761429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9700131e+05 2.2800000e+02 1.1761429e+01]]
# buf_obs[None][env_idx]:  [9.9700131e+05 2.2800000e+02 1.1761429e+01]
# a
# key:  None
# obs:  [9.96158257e+05 3.04000000e+02 1.18328571e+01]
# 1. elem of obs:  996158.2572157142
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9714231e+05, 2.1600000e+02, 1.1171429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9714231e+05 2.1600000e+02 1.1171429e+01]]
# buf_obs[None][env_idx]:  [9.9714231e+05 2.1600000e+02 1.1171429e+01]
# a
# key:  None
# obs:  [9.96063500e+05 3.12000000e+02 1.26228571e+01]
# 1. elem of obs:  996063.4996957142
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9615825e+05, 3.0400000e+02, 1.1832857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9615825e+05 3.0400000e+02 1.1832857e+01]]
# buf_obs[None][env_idx]:  [9.9615825e+05 3.0400000e+02 1.1832857e+01]
# a
# key:  None
# obs:  [9.95659164e+05 3.44000000e+02 1.26228571e+01]
# 1. elem of obs:  995659.1643357142
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9606350e+05, 3.1200000e+02, 1.2622857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9606350e+05 3.1200000e+02 1.2622857e+01]]
# buf_obs[None][env_idx]:  [9.9606350e+05 3.1200000e+02 1.2622857e+01]
# a
# key:  None
# obs:  [9.95734826e+05 3.38000000e+02 1.28057143e+01]
# 1. elem of obs:  995734.8257414284
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9565919e+05, 3.4400000e+02, 1.2622857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9565919e+05 3.4400000e+02 1.2622857e+01]]
# buf_obs[None][env_idx]:  [9.9565919e+05 3.4400000e+02 1.2622857e+01]
# a
# key:  None
# obs:  [9.94452974e+05 4.38000000e+02 1.29614286e+01]
# 1. elem of obs:  994452.9737414285
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9573481e+05, 3.3800000e+02, 1.2805715e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9573481e+05 3.3800000e+02 1.2805715e+01]]
# buf_obs[None][env_idx]:  [9.9573481e+05 3.3800000e+02 1.2805715e+01]
# a
# key:  None
# obs:  [9.93324202e+05 5.25000000e+02 1.34571429e+01]
# 1. elem of obs:  993324.2018114284
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9445300e+05, 4.3800000e+02, 1.2961429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9445300e+05 4.3800000e+02 1.2961429e+01]]
# buf_obs[None][env_idx]:  [9.9445300e+05 4.3800000e+02 1.2961429e+01]
# a
# key:  None
# obs:  [9.93633407e+05 5.02000000e+02 1.32857143e+01]
# 1. elem of obs:  993633.406582857
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9332419e+05, 5.2500000e+02, 1.3457143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9332419e+05 5.2500000e+02 1.3457143e+01]]
# buf_obs[None][env_idx]:  [9.9332419e+05 5.2500000e+02 1.3457143e+01]
# a
# key:  None
# obs:  [9.93991762e+05 4.75000000e+02 1.28757143e+01]
# 1. elem of obs:  993991.7621542856
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9363344e+05, 5.0200000e+02, 1.3285714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9363344e+05 5.0200000e+02 1.3285714e+01]]
# buf_obs[None][env_idx]:  [9.9363344e+05 5.0200000e+02 1.3285714e+01]
# a
# key:  None
# obs:  [9.93914431e+05 4.81000000e+02 1.30728571e+01]
# 1. elem of obs:  993914.4306142855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9399175e+05, 4.7500000e+02, 1.2875714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9399175e+05 4.7500000e+02 1.2875714e+01]]
# buf_obs[None][env_idx]:  [9.9399175e+05 4.7500000e+02 1.2875714e+01]
# a
# key:  None
# obs:  [9.92605838e+05 5.81000000e+02 1.32828571e+01]
# 1. elem of obs:  992605.8376142855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9391444e+05, 4.8100000e+02, 1.3072857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9391444e+05 4.8100000e+02 1.3072857e+01]]
# buf_obs[None][env_idx]:  [9.9391444e+05 4.8100000e+02 1.3072857e+01]
# a
# key:  None
# obs:  [9.92047400e+05 6.23000000e+02 1.33642857e+01]
# 1. elem of obs:  992047.3997342855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9260581e+05, 5.8100000e+02, 1.3282857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9260581e+05 5.8100000e+02 1.3282857e+01]]
# buf_obs[None][env_idx]:  [9.9260581e+05 5.8100000e+02 1.3282857e+01]
# a
# key:  None
# obs:  [9.90709635e+05 7.23000000e+02 1.37800000e+01]
# 1. elem of obs:  990709.6347342855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9204738e+05, 6.2300000e+02, 1.3364285e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9204738e+05 6.2300000e+02 1.3364285e+01]]
# buf_obs[None][env_idx]:  [9.9204738e+05 6.2300000e+02 1.3364285e+01]
# a
# key:  None
# obs:  [9.90392378e+05 7.46000000e+02 1.42457143e+01]
# 1. elem of obs:  990392.3777942855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.907096e+05, 7.230000e+02, 1.378000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.907096e+05 7.230000e+02 1.378000e+01]]
# buf_obs[None][env_idx]:  [9.907096e+05 7.230000e+02 1.378000e+01]
# a
# key:  None
# obs:  [9.88966382e+05 8.46000000e+02 1.46442857e+01]
# 1. elem of obs:  988966.3817942855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9039238e+05, 7.4600000e+02, 1.4245714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9039238e+05 7.4600000e+02 1.4245714e+01]]
# buf_obs[None][env_idx]:  [9.9039238e+05 7.4600000e+02 1.4245714e+01]
# a
# key:  None
# obs:  [9.90429346e+05 7.46000000e+02 1.39757143e+01]
# 1. elem of obs:  990429.3459371426
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.8896638e+05, 8.4600000e+02, 1.4644286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.8896638e+05 8.4600000e+02 1.4644286e+01]]
# buf_obs[None][env_idx]:  [9.8896638e+05 8.4600000e+02 1.4644286e+01]
# a
# key:  None
# obs:  [9.91741749e+05 6.52000000e+02 1.38314286e+01]
# 1. elem of obs:  991741.7493628568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9042938e+05, 7.4600000e+02, 1.3975715e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9042938e+05 7.4600000e+02 1.3975715e+01]]
# buf_obs[None][env_idx]:  [9.9042938e+05 7.4600000e+02 1.3975715e+01]
# a
# key:  None
# obs:  [9.93123509e+05 5.52000000e+02 1.41814286e+01]
# 1. elem of obs:  993123.5090771426
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9174175e+05, 6.5200000e+02, 1.3831429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9174175e+05 6.5200000e+02 1.3831429e+01]]
# buf_obs[None][env_idx]:  [9.9174175e+05 6.5200000e+02 1.3831429e+01]
# a
# key:  None
# obs:  [9.94356060e+05 4.65000000e+02 1.41657143e+01]
# 1. elem of obs:  994356.0595785711
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9312350e+05, 5.5200000e+02, 1.4181429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9312350e+05 5.5200000e+02 1.4181429e+01]]
# buf_obs[None][env_idx]:  [9.9312350e+05 5.5200000e+02 1.4181429e+01]
# a
# key:  None
# obs:  [9.95771214e+05 3.65000000e+02 1.35042857e+01]
# 1. elem of obs:  995771.214435714
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9435606e+05, 4.6500000e+02, 1.4165714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9435606e+05 4.6500000e+02 1.4165714e+01]]
# buf_obs[None][env_idx]:  [9.9435606e+05 4.6500000e+02 1.4165714e+01]
# a
# key:  None
# obs:  [9.95487341e+05 3.86000000e+02 1.34814286e+01]
# 1. elem of obs:  995487.340845714
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9577119e+05, 3.6500000e+02, 1.3504286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9577119e+05 3.6500000e+02 1.3504286e+01]]
# buf_obs[None][env_idx]:  [9.9577119e+05 3.6500000e+02 1.3504286e+01]
# a
# key:  None
# obs:  [9.94920555e+05 4.28000000e+02 1.29485714e+01]
# 1. elem of obs:  994920.554625714
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9548731e+05, 3.8600000e+02, 1.3481428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9548731e+05 3.8600000e+02 1.3481428e+01]]
# buf_obs[None][env_idx]:  [9.9548731e+05 3.8600000e+02 1.3481428e+01]
# a
# key:  None
# obs:  [9.96214117e+05 3.28000000e+02 1.30285714e+01]
# 1. elem of obs:  996214.1169114283
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9492056e+05, 4.2800000e+02, 1.2948571e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9492056e+05 4.2800000e+02 1.2948571e+01]]
# buf_obs[None][env_idx]:  [9.9492056e+05 4.2800000e+02 1.2948571e+01]
# a
# key:  None
# obs:  [9.96734739e+05 2.88000000e+02 1.24214286e+01]
# 1. elem of obs:  996734.738625714
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9621412e+05, 3.2800000e+02, 1.3028571e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9621412e+05 3.2800000e+02 1.3028571e+01]]
# buf_obs[None][env_idx]:  [9.9621412e+05 3.2800000e+02 1.3028571e+01]
# a
# key:  None
# obs:  [9.97975639e+05 1.88000000e+02 1.28928571e+01]
# 1. elem of obs:  997975.6393399996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9673475e+05, 2.8800000e+02, 1.2421429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9673475e+05 2.8800000e+02 1.2421429e+01]]
# buf_obs[None][env_idx]:  [9.9673475e+05 2.8800000e+02 1.2421429e+01]
# a
# key:  None
# obs:  [9.98503718e+05 1.47000000e+02 1.30228571e+01]
# 1. elem of obs:  998503.717875714
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9797562e+05, 1.8800000e+02, 1.2892858e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9797562e+05 1.8800000e+02 1.2892858e+01]]
# buf_obs[None][env_idx]:  [9.9797562e+05 1.8800000e+02 1.2892858e+01]
# a
# key:  None
# obs:  [9.99804701e+05 4.70000000e+01 1.27414286e+01]
# 1. elem of obs:  999804.7013042853
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9850369e+05, 1.4700000e+02, 1.3022857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9850369e+05 1.4700000e+02 1.3022857e+01]]
# buf_obs[None][env_idx]:  [9.9850369e+05 1.4700000e+02 1.3022857e+01]
# a
# key:  None
# obs:  [9.99995632e+05 3.20000000e+01 1.27585714e+01]
# 1. elem of obs:  999995.6316114282
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9980469e+05, 4.7000000e+01, 1.2741428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9980469e+05 4.7000000e+01 1.2741428e+01]]
# buf_obs[None][env_idx]:  [9.9980469e+05 4.7000000e+01 1.2741428e+01]
# a
# key:  None
# obs:  [9.99203809e+05 9.40000000e+01 1.25628571e+01]
# 1. elem of obs:  999203.8091514282
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9999562e+05, 3.2000000e+01, 1.2758572e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9999562e+05 3.2000000e+01 1.2758572e+01]]
# buf_obs[None][env_idx]:  [9.9999562e+05 3.2000000e+01 1.2758572e+01]
# a
# key:  None
# obs:  [1.00038354e+06 0.00000000e+00 1.26242857e+01]
# 1. elem of obs:  1000383.5368142853
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9920381e+05, 9.4000000e+01, 1.2562857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9920381e+05 9.4000000e+01 1.2562857e+01]]
# buf_obs[None][env_idx]:  [9.9920381e+05 9.4000000e+01 1.2562857e+01]
# a
# key:  None
# obs:  [1.00038354e+06 0.00000000e+00 1.30242857e+01]
# 1. elem of obs:  1000383.5368142853
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00038356e+06, 0.00000000e+00, 1.26242857e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00038356e+06 0.00000000e+00 1.26242857e+01]]
# buf_obs[None][env_idx]:  [1.00038356e+06 0.00000000e+00 1.26242857e+01]
# a
# key:  None
# obs:  [9.99079806e+05 1.00000000e+02 1.26914286e+01]
# 1. elem of obs:  999079.8058142853
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00038356e+06, 0.00000000e+00, 1.30242853e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00038356e+06 0.00000000e+00 1.30242853e+01]]
# buf_obs[None][env_idx]:  [1.00038356e+06 0.00000000e+00 1.30242853e+01]
# a
# key:  None
# obs:  [9.99637670e+05 5.60000000e+01 1.21857143e+01]
# 1. elem of obs:  999637.670248571
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9907981e+05, 1.0000000e+02, 1.2691428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9907981e+05 1.0000000e+02 1.2691428e+01]]
# buf_obs[None][env_idx]:  [9.9907981e+05 1.0000000e+02 1.2691428e+01]
# a
# key:  None
# obs:  [9.98820411e+05 1.23000000e+02 1.18728571e+01]
# 1. elem of obs:  998820.4109485709
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9963769e+05, 5.6000000e+01, 1.2185715e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9963769e+05 5.6000000e+01 1.2185715e+01]]
# buf_obs[None][env_idx]:  [9.9963769e+05 5.6000000e+01 1.2185715e+01]
# a
# key:  None
# obs:  [1.00000651e+06 2.30000000e+01 1.26610714e+01]
# 1. elem of obs:  1000006.5093771424
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9882044e+05, 1.2300000e+02, 1.1872857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9882044e+05 1.2300000e+02 1.1872857e+01]]
# buf_obs[None][env_idx]:  [9.9882044e+05 1.2300000e+02 1.1872857e+01]
# a
# key:  None
# obs:  [1.00029742e+06 0.00000000e+00 1.32400000e+01]
# 1. elem of obs:  1000297.4228153568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0000065e+06, 2.3000000e+01, 1.2661072e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0000065e+06 2.3000000e+01 1.2661072e+01]]
# buf_obs[None][env_idx]:  [1.0000065e+06 2.3000000e+01 1.2661072e+01]
# a
# key:  None
# obs:  [1.00029742e+06 0.00000000e+00 1.37642857e+01]
# 1. elem of obs:  1000297.4228153568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00029744e+06, 0.00000000e+00, 1.32399998e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00029744e+06 0.00000000e+00 1.32399998e+01]]
# buf_obs[None][env_idx]:  [1.00029744e+06 0.00000000e+00 1.32399998e+01]
# a
# key:  None
# obs:  [1.00013209e+06 1.20000000e+01 1.37042857e+01]
# 1. elem of obs:  1000132.0862153567
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00029744e+06, 0.00000000e+00, 1.37642860e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00029744e+06 0.00000000e+00 1.37642860e+01]]
# buf_obs[None][env_idx]:  [1.00029744e+06 0.00000000e+00 1.37642860e+01]
# a
# key:  None
# obs:  [1.00029637e+06 0.00000000e+00 1.36314286e+01]
# 1. elem of obs:  1000296.3731924996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00013206e+06, 1.20000000e+01, 1.37042856e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00013206e+06 1.20000000e+01 1.37042856e+01]]
# buf_obs[None][env_idx]:  [1.00013206e+06 1.20000000e+01 1.37042856e+01]
# a
# key:  None
# obs:  [1.00029637e+06 0.00000000e+00 1.42371429e+01]
# 1. elem of obs:  1000296.3731924996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0002964e+06, 0.0000000e+00, 1.3631429e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0002964e+06 0.0000000e+00 1.3631429e+01]]
# buf_obs[None][env_idx]:  [1.0002964e+06 0.0000000e+00 1.3631429e+01]
# a
# key:  None
# obs:  [1.00029637e+06 0.00000000e+00 1.45028571e+01]
# 1. elem of obs:  1000296.3731924996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0002964e+06, 0.0000000e+00, 1.4237143e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0002964e+06 0.0000000e+00 1.4237143e+01]]
# buf_obs[None][env_idx]:  [1.0002964e+06 0.0000000e+00 1.4237143e+01]
# a
# key:  None
# obs:  [9.99831818e+05 3.20000000e+01 1.45171429e+01]
# 1. elem of obs:  999831.8176724996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0002964e+06, 0.0000000e+00, 1.4502857e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0002964e+06 0.0000000e+00 1.4502857e+01]]
# buf_obs[None][env_idx]:  [1.0002964e+06 0.0000000e+00 1.4502857e+01]
# a
# key:  None
# obs:  [9.98378652e+05 1.32000000e+02 1.45128571e+01]
# 1. elem of obs:  998378.6516724996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9983181e+05, 3.2000000e+01, 1.4517143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9983181e+05 3.2000000e+01 1.4517143e+01]]
# buf_obs[None][env_idx]:  [9.9983181e+05 3.2000000e+01 1.4517143e+01]
# a
# key:  None
# obs:  [9.98247905e+05 1.41000000e+02 1.53800000e+01]
# 1. elem of obs:  998247.9053424996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9837862e+05, 1.3200000e+02, 1.4512857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9837862e+05 1.3200000e+02 1.4512857e+01]]
# buf_obs[None][env_idx]:  [9.9837862e+05 1.3200000e+02 1.4512857e+01]
# a
# key:  None
# obs:  [9.98078556e+05 1.52000000e+02 1.52144286e+01]
# 1. elem of obs:  998078.5561624996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.982479e+05, 1.410000e+02, 1.538000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.982479e+05 1.410000e+02 1.538000e+01]]
# buf_obs[None][env_idx]:  [9.982479e+05 1.410000e+02 1.538000e+01]
# a
# key:  None
# obs:  [9.97636897e+05 1.81000000e+02 1.52128571e+01]
# 1. elem of obs:  997636.8965154996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9807856e+05, 1.5200000e+02, 1.5214429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9807856e+05 1.5200000e+02 1.5214429e+01]]
# buf_obs[None][env_idx]:  [9.9807856e+05 1.5200000e+02 1.5214429e+01]
# a
# key:  None
# obs:  [9.98077628e+05 1.52000000e+02 1.56957143e+01]
# 1. elem of obs:  998077.6281997852
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9763688e+05, 1.8100000e+02, 1.5212857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9763688e+05 1.8100000e+02 1.5212857e+01]]
# buf_obs[None][env_idx]:  [9.9763688e+05 1.8100000e+02 1.5212857e+01]
# a
# key:  None
# obs:  [9.98171708e+05 1.46000000e+02 1.52642857e+01]
# 1. elem of obs:  998171.7083112139
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9807762e+05, 1.5200000e+02, 1.5695714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9807762e+05 1.5200000e+02 1.5695714e+01]]
# buf_obs[None][env_idx]:  [9.9807762e+05 1.5200000e+02 1.5695714e+01]
# a
# key:  None
# obs:  [9.97591085e+05 1.84000000e+02 1.49271429e+01]
# 1. elem of obs:  997591.0854112139
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9817169e+05, 1.4600000e+02, 1.5264286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9817169e+05 1.4600000e+02 1.5264286e+01]]
# buf_obs[None][env_idx]:  [9.9817169e+05 1.4600000e+02 1.5264286e+01]
# a
# key:  None
# obs:  [9.96156647e+05 2.80000000e+02 1.50171429e+01]
# 1. elem of obs:  996156.646691214
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9759106e+05, 1.8400000e+02, 1.4927143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9759106e+05 1.8400000e+02 1.4927143e+01]]
# buf_obs[None][env_idx]:  [9.9759106e+05 1.8400000e+02 1.4927143e+01]
# a
# key:  None
# obs:  [9.96561704e+05 2.53000000e+02 1.55271429e+01]
# 1. elem of obs:  996561.7040854996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9615662e+05, 2.8000000e+02, 1.5017143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9615662e+05 2.8000000e+02 1.5017143e+01]]
# buf_obs[None][env_idx]:  [9.9615662e+05 2.8000000e+02 1.5017143e+01]
# a
# key:  None
# obs:  [9.96778867e+05 2.39000000e+02 1.61014286e+01]
# 1. elem of obs:  996778.8667054996
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9656169e+05, 2.5300000e+02, 1.5527143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9656169e+05 2.5300000e+02 1.5527143e+01]]
# buf_obs[None][env_idx]:  [9.9656169e+05 2.5300000e+02 1.5527143e+01]
# a
# key:  None
# obs:  [9.97052317e+05 2.22000000e+02 1.65700000e+01]
# 1. elem of obs:  997052.3172669281
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9677888e+05, 2.3900000e+02, 1.6101429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9677888e+05 2.3900000e+02 1.6101429e+01]]
# buf_obs[None][env_idx]:  [9.9677888e+05 2.3900000e+02 1.6101429e+01]
# a
# key:  None
# obs:  [9.98095183e+05 1.59000000e+02 1.69214286e+01]
# 1. elem of obs:  998095.1833569282
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.970523e+05, 2.220000e+02, 1.657000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.970523e+05 2.220000e+02 1.657000e+01]]
# buf_obs[None][env_idx]:  [9.970523e+05 2.220000e+02 1.657000e+01]
# a
# key:  None
# obs:  [9.99160167e+05 9.60000000e+01 1.64285714e+01]
# 1. elem of obs:  999160.1673069282
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9809519e+05, 1.5900000e+02, 1.6921429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9809519e+05 1.5900000e+02 1.6921429e+01]]
# buf_obs[None][env_idx]:  [9.9809519e+05 1.5900000e+02 1.6921429e+01]
# a
# key:  None
# obs:  [9.97910347e+05 1.72000000e+02 1.66171429e+01]
# 1. elem of obs:  997910.3473069282
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9916019e+05, 9.6000000e+01, 1.6428572e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9916019e+05 9.6000000e+01 1.6428572e+01]]
# buf_obs[None][env_idx]:  [9.9916019e+05 9.6000000e+01 1.6428572e+01]
# a
# key:  None
# obs:  [9.99570400e+05 7.20000000e+01 1.70814286e+01]
# 1. elem of obs:  999570.3998783568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9791038e+05, 1.7200000e+02, 1.6617144e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9791038e+05 1.7200000e+02 1.6617144e+01]]
# buf_obs[None][env_idx]:  [9.9791038e+05 1.7200000e+02 1.6617144e+01]
# a
# key:  None
# obs:  [9.98185421e+05 1.53000000e+02 1.71742857e+01]
# 1. elem of obs:  998185.4205683569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9957038e+05, 7.2000000e+01, 1.7081429e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9957038e+05 7.2000000e+01 1.7081429e+01]]
# buf_obs[None][env_idx]:  [9.9957038e+05 7.2000000e+01 1.7081429e+01]
# a
# key:  None
# obs:  [9.96466275e+05 2.53000000e+02 1.69014286e+01]
# 1. elem of obs:  996466.2745683569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9818544e+05, 1.5300000e+02, 1.7174286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9818544e+05 1.5300000e+02 1.7174286e+01]]
# buf_obs[None][env_idx]:  [9.9818544e+05 1.5300000e+02 1.7174286e+01]
# a
# key:  None
# obs:  [9.97242963e+05 2.07000000e+02 1.68057143e+01]
# 1. elem of obs:  997242.9628169284
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9646625e+05, 2.5300000e+02, 1.6901428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9646625e+05 2.5300000e+02 1.6901428e+01]]
# buf_obs[None][env_idx]:  [9.9646625e+05 2.5300000e+02 1.6901428e+01]
# a
# key:  None
# obs:  [9.98921854e+05 1.07000000e+02 1.73500000e+01]
# 1. elem of obs:  998921.8536740713
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9724294e+05, 2.0700000e+02, 1.6805714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9724294e+05 2.0700000e+02 1.6805714e+01]]
# buf_obs[None][env_idx]:  [9.9724294e+05 2.0700000e+02 1.6805714e+01]
# a
# key:  None
# obs:  [9.97862445e+05 1.68000000e+02 1.76314286e+01]
# 1. elem of obs:  997862.4453240712
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.989219e+05, 1.070000e+02, 1.735000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.989219e+05 1.070000e+02 1.735000e+01]]
# buf_obs[None][env_idx]:  [9.989219e+05 1.070000e+02 1.735000e+01]
# a
# key:  None
# obs:  [9.98496542e+05 1.32000000e+02 1.72142857e+01]
# 1. elem of obs:  998496.542021214
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9786244e+05, 1.6800000e+02, 1.7631428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9786244e+05 1.6800000e+02 1.7631428e+01]]
# buf_obs[None][env_idx]:  [9.9786244e+05 1.6800000e+02 1.7631428e+01]
# a
# key:  None
# obs:  [9.97066328e+05 2.15000000e+02 1.73942857e+01]
# 1. elem of obs:  997066.327521214
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9849656e+05, 1.3200000e+02, 1.7214285e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9849656e+05 1.3200000e+02 1.7214285e+01]]
# buf_obs[None][env_idx]:  [9.9849656e+05 1.3200000e+02 1.7214285e+01]
# a
# key:  None
# obs:  [9.96456919e+05 2.50000000e+02 1.73585714e+01]
# 1. elem of obs:  996456.918721214
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9706631e+05, 2.1500000e+02, 1.7394285e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9706631e+05 2.1500000e+02 1.7394285e+01]]
# buf_obs[None][env_idx]:  [9.9706631e+05 2.1500000e+02 1.7394285e+01]
# a
# key:  None
# obs:  [9.96543625e+05 2.45000000e+02 1.79142857e+01]
# 1. elem of obs:  996543.6247854998
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9645694e+05, 2.5000000e+02, 1.7358572e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9645694e+05 2.5000000e+02 1.7358572e+01]]
# buf_obs[None][env_idx]:  [9.9645694e+05 2.5000000e+02 1.7358572e+01]
# a
# key:  None
# obs:  [9.9824378e+05 1.5000000e+02 1.7700000e+01]
# 1. elem of obs:  998243.7800712141
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9654362e+05, 2.4500000e+02, 1.7914286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9654362e+05 2.4500000e+02 1.7914286e+01]]
# buf_obs[None][env_idx]:  [9.9654362e+05 2.4500000e+02 1.7914286e+01]
# a
# key:  None
# obs:  [1.00001201e+06 5.00000000e+01 1.78185714e+01]
# 1. elem of obs:  1000012.010071214
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9824375e+05, 1.5000000e+02, 1.7700001e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9824375e+05 1.5000000e+02 1.7700001e+01]]
# buf_obs[None][env_idx]:  [9.9824375e+05 1.5000000e+02 1.7700001e+01]
# a
# key:  None
# obs:  [1.00090205e+06 0.00000000e+00 1.77002857e+01]
# 1. elem of obs:  1000902.0477140712
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0000120e+06, 5.0000000e+01, 1.7818571e+01]], dtype=float32))])
# buf_obs[None]:  [[1.0000120e+06 5.0000000e+01 1.7818571e+01]]
# buf_obs[None][env_idx]:  [1.0000120e+06 5.0000000e+01 1.7818571e+01]
# a
# key:  None
# obs:  [1.00090205e+06 0.00000000e+00 1.78771429e+01]
# 1. elem of obs:  1000902.0477140712
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00090206e+06, 0.00000000e+00, 1.77002850e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00090206e+06 0.00000000e+00 1.77002850e+01]]
# buf_obs[None][env_idx]:  [1.00090206e+06 0.00000000e+00 1.77002850e+01]
# a
# key:  None
# obs:  [1.00032941e+06 3.20000000e+01 1.79757143e+01]
# 1. elem of obs:  1000329.4070740712
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00090206e+06, 0.00000000e+00, 1.78771420e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00090206e+06 0.00000000e+00 1.78771420e+01]]
# buf_obs[None][env_idx]:  [1.00090206e+06 0.00000000e+00 1.78771420e+01]
# a
# key:  None
# obs:  [1.00090405e+06 0.00000000e+00 1.81771429e+01]
# 1. elem of obs:  1000904.054708357
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00032944e+06, 3.20000000e+01, 1.79757137e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00032944e+06 3.20000000e+01 1.79757137e+01]]
# buf_obs[None][env_idx]:  [1.00032944e+06 3.20000000e+01 1.79757137e+01]
# a
# key:  None
# obs:  [9.99084523e+05 1.00000000e+02 1.88671429e+01]
# 1. elem of obs:  999084.522708357
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00090406e+06, 0.00000000e+00, 1.81771431e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00090406e+06 0.00000000e+00 1.81771431e+01]]
# buf_obs[None][env_idx]:  [1.00090406e+06 0.00000000e+00 1.81771431e+01]
# a
# key:
# WARNING:root:---@ step 100 / 2048, adding latest part of trajectory to rollout-buffer:
# WARNING:root:last observation, actions, rewards, last_dones, values, log_probs---
# WARNING:root:-> stable_baselines3/common/on_policy_algorithm.py : collect_rollouts()step 100/2048
# WARNING:root:env.step(clipped_actions)
# WARNING:root:n_rollout_steps : 2048
#  None
# obs:  [9.97195922e+05 2.00000000e+02 1.89585714e+01]
# 1. elem of obs:  997195.9217083569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9908450e+05, 1.0000000e+02, 1.8867144e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9908450e+05 1.0000000e+02 1.8867144e+01]]
# buf_obs[None][env_idx]:  [9.9908450e+05 1.0000000e+02 1.8867144e+01]
# a
# key:  None
# obs:  [9.95298169e+05 3.00000000e+02 1.89285714e+01]
# 1. elem of obs:  995298.1687083569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9719594e+05, 2.0000000e+02, 1.8958570e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9719594e+05 2.0000000e+02 1.8958570e+01]]
# buf_obs[None][env_idx]:  [9.9719594e+05 2.0000000e+02 1.8958570e+01]
# a
# key:  None
# obs:  [9.93403419e+05 4.00000000e+02 1.84371429e+01]
# 1. elem of obs:  993403.4187083569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9529819e+05, 3.0000000e+02, 1.8928572e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9529819e+05 3.0000000e+02 1.8928572e+01]]
# buf_obs[None][env_idx]:  [9.9529819e+05 3.0000000e+02 1.8928572e+01]
# a
# key:  None
# obs:  [9.95245289e+05 3.00000000e+02 1.84557143e+01]
# 1. elem of obs:  995245.2892797855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9340344e+05, 4.0000000e+02, 1.8437143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9340344e+05 4.0000000e+02 1.8437143e+01]]
# buf_obs[None][env_idx]:  [9.9340344e+05 4.0000000e+02 1.8437143e+01]
# a
# key:  None
# obs:  [9.94598693e+05 3.35000000e+02 1.85100000e+01]
# 1. elem of obs:  994598.6933297855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9524531e+05, 3.0000000e+02, 1.8455715e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9524531e+05 3.0000000e+02 1.8455715e+01]]
# buf_obs[None][env_idx]:  [9.9524531e+05 3.0000000e+02 1.8455715e+01]
# a
# key:  None
# obs:  [9.92745842e+05 4.35000000e+02 1.77742857e+01]
# 1. elem of obs:  992745.8423297855
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.945987e+05, 3.350000e+02, 1.851000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.945987e+05 3.350000e+02 1.851000e+01]]
# buf_obs[None][env_idx]:  [9.945987e+05 3.350000e+02 1.851000e+01]
# a
# key:  None
# obs:  [9.94343928e+05 3.45000000e+02 1.70700000e+01]
# 1. elem of obs:  994343.9283583569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9274581e+05, 4.3500000e+02, 1.7774286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9274581e+05 4.3500000e+02 1.7774286e+01]]
# buf_obs[None][env_idx]:  [9.9274581e+05 4.3500000e+02 1.7774286e+01]
# a
# key:  None
# obs:  [9.95486475e+05 2.78000000e+02 1.75642857e+01]
# 1. elem of obs:  995486.4746683569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9434394e+05, 3.4500000e+02, 1.7070000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9434394e+05 3.4500000e+02 1.7070000e+01]]
# buf_obs[None][env_idx]:  [9.9434394e+05 3.4500000e+02 1.7070000e+01]
# a
# key:  None
# obs:  [9.93728290e+05 3.78000000e+02 1.74885714e+01]
# 1. elem of obs:  993728.2896683569
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9548650e+05, 2.7800000e+02, 1.7564285e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9548650e+05 2.7800000e+02 1.7564285e+01]]
# buf_obs[None][env_idx]:  [9.9548650e+05 2.7800000e+02 1.7564285e+01]
# a
# key:  None
# obs:  [9.95475398e+05 2.78000000e+02 1.80928571e+01]
# 1. elem of obs:  995475.3979540712
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9372831e+05, 3.7800000e+02, 1.7488571e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9372831e+05 3.7800000e+02 1.7488571e+01]]
# buf_obs[None][env_idx]:  [9.9372831e+05 3.7800000e+02 1.7488571e+01]
# a
# key:  None
# obs:  [9.96433360e+05 2.25000000e+02 1.82071429e+01]
# 1. elem of obs:  996433.360461214
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9547538e+05, 2.7800000e+02, 1.8092857e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9547538e+05 2.7800000e+02 1.8092857e+01]]
# buf_obs[None][env_idx]:  [9.9547538e+05 2.7800000e+02 1.8092857e+01]
# a
# key:  None
# obs:  [9.97997609e+05 1.39000000e+02 1.79814286e+01]
# 1. elem of obs:  997997.6089326425
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9643338e+05, 2.2500000e+02, 1.8207144e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9643338e+05 2.2500000e+02 1.8207144e+01]]
# buf_obs[None][env_idx]:  [9.9643338e+05 2.2500000e+02 1.8207144e+01]
# a
# key:  None
# obs:  [9.96197668e+05 2.39000000e+02 1.77400000e+01]
# 1. elem of obs:  996197.6679326425
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9799762e+05, 1.3900000e+02, 1.7981428e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9799762e+05 1.3900000e+02 1.7981428e+01]]
# buf_obs[None][env_idx]:  [9.9799762e+05 1.3900000e+02 1.7981428e+01]
# a
# key:  None
# obs:  [9.97969894e+05 1.39000000e+02 1.75000000e+01]
# 1. elem of obs:  997969.8939326425
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.961977e+05, 2.390000e+02, 1.774000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.961977e+05 2.390000e+02 1.774000e+01]]
# buf_obs[None][env_idx]:  [9.961977e+05 2.390000e+02 1.774000e+01]
# a
# key:  None
# obs:  [9.99718144e+05 3.90000000e+01 1.86828571e+01]
# 1. elem of obs:  999718.1439326425
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.979699e+05, 1.390000e+02, 1.750000e+01]], dtype=float32))])
# buf_obs[None]:  [[9.979699e+05 1.390000e+02 1.750000e+01]]
# buf_obs[None][env_idx]:  [9.979699e+05 1.390000e+02 1.750000e+01]
# a
# key:  None
# obs:  [9.97847990e+05 1.39000000e+02 1.90071429e+01]
# 1. elem of obs:  997847.9899326426
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9971812e+05, 3.9000000e+01, 1.8682858e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9971812e+05 3.9000000e+01 1.8682858e+01]]
# buf_obs[None][env_idx]:  [9.9971812e+05 3.9000000e+01 1.8682858e+01]
# a
# key:  None
# obs:  [9.99746804e+05 3.90000000e+01 1.92957143e+01]
# 1. elem of obs:  999746.8035040711
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9784800e+05, 1.3900000e+02, 1.9007143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9784800e+05 1.3900000e+02 1.9007143e+01]]
# buf_obs[None][env_idx]:  [9.9784800e+05 1.3900000e+02 1.9007143e+01]
# a
# key:  None
# obs:  [1.00049858e+06 0.00000000e+00 1.94014286e+01]
# 1. elem of obs:  1000498.5838283568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9974681e+05, 3.9000000e+01, 1.9295713e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9974681e+05 3.9000000e+01 1.9295713e+01]]
# buf_obs[None][env_idx]:  [9.9974681e+05 3.9000000e+01 1.9295713e+01]
# a
# key:  None
# obs:  [9.98847813e+05 8.50000000e+01 1.99071429e+01]
# 1. elem of obs:  998847.8132783568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00049856e+06, 0.00000000e+00, 1.94014282e+01]], dtype=float32))])
# buf_obs[None]:  [[1.00049856e+06 0.00000000e+00 1.94014282e+01]]
# buf_obs[None][env_idx]:  [1.00049856e+06 0.00000000e+00 1.94014282e+01]
# a
# key:  None
# obs:  [9.97692044e+05 1.43000000e+02 1.99271429e+01]
# 1. elem of obs:  997692.0443783568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9884781e+05, 8.5000000e+01, 1.9907143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9884781e+05 8.5000000e+01 1.9907143e+01]]
# buf_obs[None][env_idx]:  [9.9884781e+05 8.5000000e+01 1.9907143e+01]
# a
# key:  None
# obs:  [9.97911024e+05 1.32000000e+02 2.01357143e+01]
# 1. elem of obs:  997911.0237512139
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9769206e+05, 1.4300000e+02, 1.9927143e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9769206e+05 1.4300000e+02 1.9927143e+01]]
# buf_obs[None][env_idx]:  [9.9769206e+05 1.4300000e+02 1.9927143e+01]
# a
# key:  None
# obs:  [9.99922582e+05 3.20000000e+01 2.05342857e+01]
# 1. elem of obs:  999922.5816083568
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9791100e+05, 1.3200000e+02, 2.0135714e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9791100e+05 1.3200000e+02 2.0135714e+01]]
# buf_obs[None][env_idx]:  [9.9791100e+05 1.3200000e+02 2.0135714e+01]
# a
# key:  None
# obs:  [1.00057902e+06 0.00000000e+00 2.06671429e+01]
# 1. elem of obs:  1000579.021654071
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9992256e+05, 3.2000000e+01, 2.0534286e+01]], dtype=float32))])
# buf_obs[None]:  [[9.9992256e+05 3.2000000e+01 2.0534286e+01]]
# buf_obs[None][env_idx]:  [9.9992256e+05 3.2000000e+01 2.0534286e+01]
# a
# key:  None
# ...
# buf_obs[None]:  [[1.01488e+06 1.03900e+03 1.10410e+02]]
# buf_obs[None][env_idx]:  [1.01488e+06 1.03900e+03 1.10410e+02]
# a
# key:  None
# obs:  [1.0074893e+06 1.1060000e+03 1.1088000e+02]
# 1. elem of obs:  1007489.3017376851
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.003828e+06, 1.139000e+03, 1.110600e+02]], dtype=float32))])
# buf_obs[None]:  [[1.003828e+06 1.139000e+03 1.110600e+02]]
# buf_obs[None][env_idx]:  [1.003828e+06 1.139000e+03 1.110600e+02]
# a
# key:  None
# obs:  [1.01280622e+06 1.05800000e+03 1.07790000e+02]
# 1. elem of obs:  1012806.2194976851
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0074893e+06, 1.1060000e+03, 1.1088000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.0074893e+06 1.1060000e+03 1.1088000e+02]]
# buf_obs[None][env_idx]:  [1.0074893e+06 1.1060000e+03 1.1088000e+02]
# a
# key:  None
# obs:  [1.01420609e+06 1.04500000e+03 1.08430000e+02]
# 1. elem of obs:  1014206.0882276851
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.01280625e+06, 1.05800000e+03, 1.07790001e+02]], dtype=float32))])
# buf_obs[None]:  [[1.01280625e+06 1.05800000e+03 1.07790001e+02]]
# buf_obs[None][env_idx]:  [1.01280625e+06 1.05800000e+03 1.07790001e+02]
# a
# key:  None
# obs:  [1.00335225e+06 1.14500000e+03 1.05710000e+02]
# 1. elem of obs:  1003352.2452276851
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.01420606e+06, 1.04500000e+03, 1.08430000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.01420606e+06 1.04500000e+03 1.08430000e+02]]
# buf_obs[None][env_idx]:  [1.01420606e+06 1.04500000e+03 1.08430000e+02]
# a
# key:  None
# obs:  [9.92770674e+05 1.24500000e+03 1.07110000e+02]
# 1. elem of obs:  992770.6742276851
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.00335225e+06, 1.14500000e+03, 1.05709999e+02]], dtype=float32))])
# buf_obs[None]:  [[1.00335225e+06 1.14500000e+03 1.05709999e+02]]
# buf_obs[None][env_idx]:  [1.00335225e+06 1.14500000e+03 1.05709999e+02]
# a
# key:  None
# obs:  [9.95873758e+05 1.21600000e+03 1.09990000e+02]
# 1. elem of obs:  995873.7580376851
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.927707e+05, 1.245000e+03, 1.071100e+02]], dtype=float32))])
# buf_obs[None]:  [[9.927707e+05 1.245000e+03 1.071100e+02]]
# buf_obs[None][env_idx]:  [9.927707e+05 1.245000e+03 1.071100e+02]
# a
# key:  None
# obs:  [1.0027962e+06 1.1530000e+03 1.0995000e+02]
# 1. elem of obs:  1002796.198667685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9587375e+05, 1.2160000e+03, 1.0999000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.9587375e+05 1.2160000e+03 1.0999000e+02]]
# buf_obs[None][env_idx]:  [9.9587375e+05 1.2160000e+03 1.0999000e+02]
# a
# key:  None
# obs:  [1.0027962e+06 1.1530000e+03 1.1006000e+02]
# 1. elem of obs:  1002796.198667685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0027962e+06, 1.1530000e+03, 1.0995000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.0027962e+06 1.1530000e+03 1.0995000e+02]]
# buf_obs[None][env_idx]:  [1.0027962e+06 1.1530000e+03 1.0995000e+02]
# a
# key:  None
# obs:  [1.01379119e+06 1.05300000e+03 1.11730000e+02]
# 1. elem of obs:  1013791.192667685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0027962e+06, 1.1530000e+03, 1.1006000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.0027962e+06 1.1530000e+03 1.1006000e+02]]
# buf_obs[None][env_idx]:  [1.0027962e+06 1.1530000e+03 1.1006000e+02]
# a
# key:  None
# obs:  [1.02350198e+06 9.66000000e+02 1.11800000e+02]
# 1. elem of obs:  1023501.982157685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# WARNING:root:---@ step 2000 / 2048, adding latest part of trajectory to rollout-buffer:
# WARNING:root:last observation, actions, rewards, last_dones, values, log_probs---
# WARNING:root:-> stable_baselines3/common/on_policy_algorithm.py : collect_rollouts()step 2000/2048
# WARNING:root:env.step(clipped_actions)
# WARNING:root:n_rollout_steps : 2048
# buf_obs:  OrderedDict([(None, array([[1.0137912e+06, 1.0530000e+03, 1.1173000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.0137912e+06 1.0530000e+03 1.1173000e+02]]
# buf_obs[None][env_idx]:  [1.0137912e+06 1.0530000e+03 1.1173000e+02]
# a
# key:  None
# obs:  [1.0123108e+06 1.0660000e+03 1.1123000e+02]
# 1. elem of obs:  1012310.8021576849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.023502e+06, 9.660000e+02, 1.118000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.023502e+06 9.660000e+02 1.118000e+02]]
# buf_obs[None][env_idx]:  [1.023502e+06 9.660000e+02 1.118000e+02]
# a
# key:  None
# obs:  [1.02053359e+06 9.92000000e+02 1.11790000e+02]
# 1. elem of obs:  1020533.5911376849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0123108e+06, 1.0660000e+03, 1.1123000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.0123108e+06 1.0660000e+03 1.1123000e+02]]
# buf_obs[None][env_idx]:  [1.0123108e+06 1.0660000e+03 1.1123000e+02]
# a
# key:  None
# obs:  [1.01146955e+06 1.07300000e+03 1.11570000e+02]
# 1. elem of obs:  1011469.5461476849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.02053356e+06, 9.92000000e+02, 1.11790001e+02]], dtype=float32))])
# buf_obs[None]:  [[1.02053356e+06 9.92000000e+02 1.11790001e+02]]
# buf_obs[None][env_idx]:  [1.02053356e+06 9.92000000e+02 1.11790001e+02]
# a
# key:  None
# obs:  [1.00722565e+06 1.11100000e+03 1.11460000e+02]
# 1. elem of obs:  1007225.6464876849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.01146956e+06, 1.07300000e+03, 1.11570000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.01146956e+06 1.07300000e+03 1.11570000e+02]]
# buf_obs[None][env_idx]:  [1.01146956e+06 1.07300000e+03 1.11570000e+02]
# a
# key:  None
# obs:  [9.960685e+05 1.211000e+03 1.105200e+02]
# 1. elem of obs:  996068.500487685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[1.0072256e+06, 1.1110000e+03, 1.1146000e+02]], dtype=float32))])
# buf_obs[None]:  [[1.0072256e+06 1.1110000e+03 1.1146000e+02]]
# buf_obs[None][env_idx]:  [1.0072256e+06 1.1110000e+03 1.1146000e+02]
# a
# key:  None
# obs:  [9.98055871e+05 1.19300000e+03 1.09490000e+02]
# 1. elem of obs:  998055.871127685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.960685e+05, 1.211000e+03, 1.105200e+02]], dtype=float32))])
# buf_obs[None]:  [[9.960685e+05 1.211000e+03 1.105200e+02]]
# buf_obs[None][env_idx]:  [9.960685e+05 1.211000e+03 1.105200e+02]
# a
# key:  None
# obs:  [9.87095922e+05 1.29300000e+03 1.09900000e+02]
# 1. elem of obs:  987095.9221276849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.980559e+05, 1.193000e+03, 1.094900e+02]], dtype=float32))])
# buf_obs[None]:  [[9.980559e+05 1.193000e+03 1.094900e+02]]
# buf_obs[None][env_idx]:  [9.980559e+05 1.193000e+03 1.094900e+02]
# a
# key:  None
# obs:  [9.98074932e+05 1.19300000e+03 1.09110000e+02]
# 1. elem of obs:  998074.9321276849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.8709594e+05, 1.2930000e+03, 1.0990000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.8709594e+05 1.2930000e+03 1.0990000e+02]]
# buf_obs[None][env_idx]:  [9.8709594e+05 1.2930000e+03 1.0990000e+02]
# a
# key:  None
# obs:  [9.96327426e+05 1.20900000e+03 1.09950000e+02]
# 1. elem of obs:  996327.426367685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9807494e+05, 1.1930000e+03, 1.0911000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.9807494e+05 1.1930000e+03 1.0911000e+02]]
# buf_obs[None][env_idx]:  [9.9807494e+05 1.1930000e+03 1.0911000e+02]
# a
# key:  None
# obs:  [9.8829305e+05 1.2820000e+03 1.1103000e+02]
# 1. elem of obs:  988293.0500176849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9632744e+05, 1.2090000e+03, 1.0995000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.9632744e+05 1.2090000e+03 1.0995000e+02]]
# buf_obs[None][env_idx]:  [9.9632744e+05 1.2090000e+03 1.0995000e+02]
# a
# key:  None
# obs:  [9.86737076e+05 1.29600000e+03 1.12120000e+02]
# 1. elem of obs:  986737.075597685
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.8829306e+05, 1.2820000e+03, 1.1103000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.8829306e+05 1.2820000e+03 1.1103000e+02]]
# buf_obs[None][env_idx]:  [9.8829306e+05 1.2820000e+03 1.1103000e+02]
# a
# key:  None
# obs:  [9.92113454e+05 1.24800000e+03 1.13950000e+02]
# 1. elem of obs:  992113.4538376849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.8673706e+05, 1.2960000e+03, 1.1212000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.8673706e+05 1.2960000e+03 1.1212000e+02]]
# buf_obs[None][env_idx]:  [9.8673706e+05 1.2960000e+03 1.1212000e+02]
# a
# key:  None
# obs:  [9.80707059e+05 1.34800000e+03 1.13300000e+02]
# 1. elem of obs:  980707.0588376849
# type of 1. elem:  <class 'numpy.float64'>
# len of obs:  3
# type obs:  <class 'numpy.ndarray'>
# env_ids:  0
# buf_obs:  OrderedDict([(None, array([[9.9211344e+05, 1.2480000e+03, 1.1395000e+02]], dtype=float32))])
# buf_obs[None]:  [[9.9211344e+05 1.2480000e+03 1.1395000e+02]]
# buf_obs[None][env_idx]:  [9.9211344e+05 1.2480000e+03 1.1395000e+02]
# a
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-7a92a1b872f6> in <module>
# ----> 1 model.learn(total_timesteps= 100000)
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     389             tb_log_name=tb_log_name,
#     390             eval_log_path=eval_log_path,
# --> 391             reset_num_timesteps=reset_num_timesteps,
#     392         )
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     305                                                       callback,
#     306                                                       self.rollout_buffer,
# --> 307                                                       n_rollout_steps=self.n_steps)
#     308
#     309             if continue_training is False:
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     222             #####
#     223
# --> 224             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     225
#     226             self.num_timesteps += env.num_envs
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     161         """
#     162         self.step_async(actions)
# --> 163         return self.step_wait()
#     164
#     165     def get_images(self) -> Sequence[np.ndarray]:
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      51         for env_idx in range(self.num_envs):
#      52             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 53                 self.actions[env_idx]
#      54             )
#      55             ##### BCAP
#
# ~\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\environment\FinancialMarketEnv.py in step(self, actions)
#     368         ##### IF WE ARE IN THE TERMINAL STATE #####
#     369         if self.terminal_state:
# --> 370             return _terminate()
#     371         ##### IF WE ARE NOT YET IN THE TERMINAL STATE #####
#     372         else:
#
# ~\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\environment\FinancialMarketEnv.py in _terminate()
#     229             self.memories["buy_trades"].append(0)
#     230             # SAVING MEMORIES TO CSV
# --> 231             _save_results()
#     232             return [self.state_flattened, self.reward, self.terminal_state, {}]
#     233
#
# ~\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\environment\FinancialMarketEnv.py in _save_results()
#     180             dates = pd.DataFrame({"datadate": self.memories["datadates"]})
#     181             dates.to_csv(os.path.join(self.results_dir, "datadates",
# --> 182                                         f"datadates"
#     183                                         f"_{self.mode}"
#     184                                         f"_{self.model_name}"
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dummyresults\\datadates\\datadates_train_ppo_ep1_totalSteps_2000_finalStateCounter_1.csv'
