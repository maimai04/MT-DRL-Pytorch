# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# own code library
from plotting import *
# Out:
# (config) no crisis measure selected.

# %%
abspath = r"C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch"

# %% [markdown]
# #### Import and display raw datasets (US -> DJIA /Dow30 components, Japan -> TOPIX core 30 components)

# %%
df_us = pd.read_csv(os.path.join(abspath, "data", "raw", "US_stocks_WDB.csv"), index_col=0)
df_jp = pd.read_csv(os.path.join(abspath, "data", "raw", "JP_stocks_WDB.csv"), index_col=0)

# %% [markdown]
# # Japan dataset

# %%
comps_jp = df_jp.conm.unique()
comps_jp.sort()
print("japan companies (name) : \n", comps_jp)
df_jp.head()
# Out:
# japan companies (name) :
#  ['ASTELLAS PHARMA INC' 'CENTRAL JAPAN RAILWAY CORP'
#  'DAIICHI SANKYO COMPANY LTD' 'DAIKIN INDUSTRIES LTD' 'FANUC CORP'
#  'HITACHI LTD' 'HONDA MOTOR CO LTD' 'HOYA CORP' 'ITOCHU CORP' 'KAO CORP'
#  'KDDI CORP' 'KEYENCE CORP' 'MITSUBISHI CORP'
#  'MITSUBISHI UFJ FINANCIAL GRP' 'MITSUI & CO LTD'
#  'MIZUHO FINANCIAL GROUP INC' 'MURATA MANUFACTURING CO LTD' 'NIDEC CORP'
#  'NINTENDO CO LTD' 'NIPPON TELEGRAPH & TELEPHONE'
#  'RECRUIT HOLDINGS CO LTD' 'SEVEN & I HOLDINGS CO LTD'
#  'SHIN-ETSU CHEMICAL CO LTD' 'SOFTBANK GROUP CORP'
#  'SONY GROUP CORPORATION' 'SUMITOMO MITSUI FINANCIAL GR'
#  'TAKEDA PHARMACEUTICAL CO LTD' 'TOKIO MARINE HOLDINGS INC'
#  'TOYOTA MOTOR CORP']
#         iid  datadate                        conm  ajexdi         cshoc  \
# gvkey
# 100668  01W  19950104         ASTELLAS PHARMA INC     5.0  3.233047e+08
# 100336  01W  19950104  DAIICHI SANKYO COMPANY LTD     3.3  4.051930e+08
# 101138  01W  19950104       DAIKIN INDUSTRIES LTD     1.0  2.638140e+08
# 100048  01W  19950104                  FANUC CORP     1.0  2.393276e+08
# 5650    01W  19950104                 HITACHI LTD     0.2  3.287147e+09
#
#            cshtrd   prccd   prchd   prcld  prcstd  divd  anncdate      trfd  \
# gvkey
# 100668   136000.0  2070.0  2070.0  2060.0    10.0   NaN       NaN  1.037670
# 100336    77000.0  2480.0  2480.0  2470.0    10.0   NaN       NaN  1.040363
# 101138    46000.0   884.0   885.0   881.0    10.0   NaN       NaN  1.083172
# 100048    56400.0  4680.0  4690.0  4650.0    10.0   NaN       NaN  1.032267
# 5650    1674000.0   997.0   997.0   989.0    10.0   NaN       NaN  1.089999
#
#                 isin    sedol
# gvkey
# 100668  JP3942400007  6985383
# 100336  JP3475350009  B0J7D91
# 101138  JP3481800005  6250724
# 100048  JP3802400006  6356934
# 5650    JP3788600009  6429104

# %%
### NOTE: we see we don't have any tickers here, like in the us dataset, only the company name.
# This is a bit unpractical, so let's manualy add tickers:
jp_tickers = ["ALPMY","CJPRY","DSNKY","DKILY","FANUY","HTHIY","HMC","HOCPF","ITOCY","KAOCF","KDDIY",
              "KYCCF","MBC","MUFG","MITSY","MFG","MRAAY","NJDCY","NTDOY","NTTYY","RCRRF","SVNDY","SHECY",
              "SFTBY","SONY","SMFG","TAK","TKOMY","TM"]

df_jp["tic"] = df_jp["conm"]
for tic, name in zip(jp_tickers, comps_jp):
    #print(f"{tic}, {name}")
    df_jp.loc[df_jp["conm"] == name, "tic"] = tic
df_jp.head(2)
# Out:
#         iid  datadate                        conm  ajexdi        cshoc  \
# gvkey
# 100668  01W  19950104         ASTELLAS PHARMA INC     5.0  323304657.0
# 100336  01W  19950104  DAIICHI SANKYO COMPANY LTD     3.3  405193000.0
#
#           cshtrd   prccd   prchd   prcld  prcstd  divd  anncdate      trfd  \
# gvkey
# 100668  136000.0  2070.0  2070.0  2060.0    10.0   NaN       NaN  1.037670
# 100336   77000.0  2480.0  2480.0  2470.0    10.0   NaN       NaN  1.040363
#
#                 isin    sedol    tic
# gvkey
# 100668  JP3942400007  6985383  ALPMY
# 100336  JP3475350009  B0J7D91  DSNKY

# %%
df_jp["log_prccd"] = np.log(df_jp["prccd"])
jp_tics = df_jp["tic"].unique()
jp_tics.sort()

# %%
plot_historical_ts(df=df_jp,
                   subplot_rows=2, 
                   subplot_cols=1,
                   datecol="datadate",
                   comp_name_column="tic",
                   comp_names_list=jp_tics, 
                   x_cols_list=["datadate"]*2,
                   y_cols_list=["prccd", "log_prccd"],
                   titles_list=["Historical Prices Japan Stocks 1995-2021", 
                                "Historical Log Prices Japan Stocks 1995-2021"],
                   x_labels_list=["Date", "Date"],
                   y_labels_list=["Stock Price", "Log Stock Price"],
                   ylim_left_list=[df_jp["prccd"][df_jp["tic"].isin(jp_tics)].min(),
                                   df_jp["log_prccd"][df_jp["tic"].isin(jp_tics)].min()], 
                   ylim_right_list=[df_jp["prccd"][df_jp["tic"].isin(jp_tics)].max(),
                                    df_jp["log_prccd"][df_jp["tic"].isin(jp_tics)].max()],
                   figsize=(17,9), 
                   space_between_plots=0.5, 
                   legend_location="right", 
                   legend_location_exact=(0.01, -0.04, 1.12, 1.1), # (right_loc, loc,up_loc, right_loc, up_loc )
                   legend_borderpad=0.9, 
                   legend_borderaxespad=0., 
                   legend_fontsize=16., 
                   label_fontsize=15.,
                   title_fontsize=18., 
                   title_pad=18., 
                   label_pad=10.)
# Out:
# C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\dataprep\plotting.py:96: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ncol=1)

# %%
# lets getthe first and last dates for each of the japanese stocks
first_occurrence_date = {}
for tic in jp_tics:
    firstdate = df_jp.loc[df_jp["tic"] == tic]["datadate"].values[0]
    first_occurrence_date.update({tic: firstdate})
print(first_occurrence_date)

### NOTE: 
# we see that MFG (late 2000), MUFG (2001), RCRRF (2014) and SVNDY (2005) have data only after 2000, 
# so we need to exclude them (maybe keep MFG for now)
# CJPRY (1997) has data after 1995 but before 2000, so we can incude it
# ==> drop MUFG (2001), RCRRF (2014) and SVNDY (2005)
droptics = ["MUFG", "RCRRF", "SVNDY"]
# Out:
# {'ALPMY': 19950104, 'CJPRY': 19971007, 'DKILY': 19950104, 'DSNKY': 19950104, 'FANUY': 19950104, 'HMC': 19950104, 'HOCPF': 19950104, 'HTHIY': 19950104, 'ITOCY': 19950104, 'KAOCF': 19950104, 'KDDIY': 19950104, 'KYCCF': 19950104, 'MBC': 19950104, 'MFG': 20000926, 'MITSY': 19950104, 'MRAAY': 19950104, 'MUFG': 20010108, 'NJDCY': 19950104, 'NTDOY': 19950104, 'NTTYY': 19950104, 'RCRRF': 20141017, 'SFTBY': 19950120, 'SHECY': 19950104, 'SMFG': 19950104, 'SONY': 19950104, 'SVNDY': 20050901, 'TAK': 19950104, 'TKOMY': 19950104, 'TM': 19950104}

# %%
len(jp_tics) # must drop 3 of these 29 initial ticks
# Out:
# 29

# %%
df_jp = df_jp[~df_jp["tic"].isin(droptics)]
print(len(df_jp["tic"].unique())) # 33 tics remaining
df_jp["tic"].unique() # mist be 26 now
# Out:
# 26
# array(['ALPMY', 'DSNKY', 'DKILY', 'FANUY', 'HTHIY', 'HMC', 'HOCPF',
#        'ITOCY', 'KAOCF', 'KDDIY', 'KYCCF', 'MBC', 'MITSY', 'MRAAY',
#        'NJDCY', 'NTDOY', 'NTTYY', 'SHECY', 'SONY', 'SMFG', 'TAK', 'TKOMY',
#        'TM', 'SFTBY', 'CJPRY', 'MFG'], dtype=object)

# %%
# vizual sanity check for each stock
jp_tics = df_jp["tic"].unique()
jp_tics.sort()
plot_historical_ts(df=df_jp,
                   subplot_rows=2, 
                   subplot_cols=1,
                   datecol="datadate",
                   comp_name_column="tic",
                   comp_names_list=jp_tics, 
                   x_cols_list=["datadate"]*2,
                   y_cols_list=["prccd", "log_prccd"],
                   titles_list=["Historical Prices Japan Stocks 1995-2021", 
                                "Historical Log Prices Japan Stocks 1995-2021"],
                   x_labels_list=["Date", "Date"],
                   y_labels_list=["Stock Price", "Log Stock Price"],
                   ylim_left_list=[df_jp["prccd"][df_jp["tic"].isin(jp_tics)].min(),
                                   df_jp["log_prccd"][df_jp["tic"].isin(jp_tics)].min()], 
                   ylim_right_list=[df_jp["prccd"][df_jp["tic"].isin(jp_tics)].max(),
                                    df_jp["log_prccd"][df_jp["tic"].isin(jp_tics)].max()],
                   figsize=(17,9), 
                   space_between_plots=0.5, 
                   legend_location="right", 
                   legend_location_exact=(0.01, -0.04, 1.12, 1.1), # (right_loc, loc,up_loc, right_loc, up_loc )
                   legend_borderpad=0.9, 
                   legend_borderaxespad=0., 
                   legend_fontsize=16., 
                   label_fontsize=15.,
                   title_fontsize=18., 
                   title_pad=18., 
                   label_pad=10.)
# Out:
# C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\dataprep\plotting.py:96: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ncol=1)

# %%
# we see above that some stock still look weird as if they have "damaged" data or 0 stock price at certain times.
# need to check

#check for 0 stock price
for tic in df_jp["tic"].unique():
    subset = df_jp.loc[df_jp["tic"]==tic]
    print(tic)
    print(subset["prccd"].describe())
# Out:
# ALPMY
# count    12233.000000
# mean      1723.547477
# std       1814.206188
# min          7.610000
# 25%         27.130000
# 50%       1523.000000
# 75%       3210.000000
# max       6598.000000
# Name: prccd, dtype: float64
# DSNKY
# count     6680.000000
# mean      2712.200674
# std       1385.047323
# min       1178.000000
# 25%       1835.875000
# 50%       2390.000000
# 75%       3110.000000
# max      10085.000000
# Name: prccd, dtype: float64
# DKILY
# count     6722.000000
# mean      5223.504061
# std       5089.423736
# min        149.100000
# 25%       2043.250000
# 50%       2915.000000
# 75%       7319.750000
# max      24320.000000
# Name: prccd, dtype: float64
# FANUY
# count     6904.000000
# mean     11591.071603
# std       6956.297055
# min        146.500000
# 25%       5900.000000
# 50%      10115.000000
# 75%      17280.000000
# max      33450.000000
# Name: prccd, dtype: float64
# HTHIY
# count    6679.000000
# mean     1083.991915
# std      1030.872749
# min       231.000000
# 25%       607.500000
# 50%       775.000000
# 75%      1020.000000
# max      6154.000000
# Name: prccd, dtype: float64
# HMC
# count    6684.000000
# mean     3710.010697
# std      1102.373473
# min      1150.000000
# 25%      2961.500000
# 50%      3597.000000
# 75%      4357.750000
# max      8400.000000
# Name: prccd, dtype: float64
# HOCPF
# count     8602.000000
# mean      4302.764817
# std       3631.454061
# min         20.113000
# 25%       1681.250000
# 50%       3810.000000
# 75%       6650.000000
# max      15240.000000
# Name: prccd, dtype: float64
# ITOCY
# count    6683.000000
# mean     1009.326201
# std       679.266052
# min       168.000000
# 25%       495.000000
# 50%       800.000000
# 75%      1323.000000
# max      3616.000000
# Name: prccd, dtype: float64
# KAOCF
# count    6683.000000
# mean     3675.204100
# std      2182.997274
# min       960.000000
# 25%      2193.500000
# 50%      2885.000000
# 75%      4901.500000
# max      9290.000000
# Name: prccd, dtype: float64
# KDDIY
# count    1.246100e+04
# mean     2.185329e+05
# std      3.155979e+05
# min      1.828000e+01
# 25%      2.913500e+03
# 50%      4.844000e+03
# 75%      4.930000e+05
# max      1.530000e+06
# Name: prccd, dtype: float64
# KYCCF
# count     6683.000000
# mean     32181.583870
# std      17599.397488
# min       8550.000000
# 25%      19430.000000
# 50%      25210.000000
# 75%      43645.000000
# max      83790.000000
# Name: prccd, dtype: float64
# MBC
# count    6684.000000
# mean     1821.814482
# std       785.639487
# min       581.000000
# 25%      1060.000000
# 50%      1847.000000
# 75%      2414.500000
# max      3930.000000
# Name: prccd, dtype: float64
# MITSY
# count    6683.000000
# mean     1284.715248
# std       491.989630
# min       521.000000
# 25%       841.000000
# 50%      1261.000000
# 75%      1630.000000
# max      3080.000000
# Name: prccd, dtype: float64
# MRAAY
# count     6685.000000
# mean      8170.442064
# std       4664.738064
# min          0.600000
# 25%       4620.000000
# 50%       6350.000000
# 75%       9800.000000
# max      25000.000000
# Name: prccd, dtype: float64
# NJDCY
# count     9612.000000
# mean      6242.807506
# std       5292.023126
# min          9.538000
# 25%         27.800000
# 50%       6690.000000
# 75%       9210.000000
# max      29790.000000
# Name: prccd, dtype: float64
# NTDOY
# count     6676.000000
# mean     22314.975285
# std      14905.261754
# min       4590.000000
# 25%      11400.000000
# 50%      17370.000000
# 75%      27943.750000
# max      71900.000000
# Name: prccd, dtype: float64
# NTTYY
# count    7.627000e+03
# mean     3.412314e+05
# std      4.298575e+05
# min      3.257000e+02
# 25%      3.795000e+03
# 50%      5.619000e+03
# 75%      5.690000e+05
# max      1.900000e+06
# Name: prccd, dtype: float64
# SHECY
# count     6685.000000
# mean      5998.153628
# std       3308.443526
# min       1450.000000
# 25%       4030.000000
# 50%       4980.000000
# 75%       7310.000000
# max      19710.000000
# Name: prccd, dtype: float64
# SONY
# count    16372.000000
# mean      2323.709861
# std       3652.765631
# min          7.380000
# 25%         34.990000
# 50%         50.450000
# 75%       3940.000000
# max      32600.000000
# Name: prccd, dtype: float64
# SMFG
# count    6.675000e+03
# mean     1.820434e+05
# std      3.658143e+05
# min      3.350000e+02
# 25%      1.890000e+03
# 50%      3.598000e+03
# 75%      4.945000e+03
# max      1.380000e+06
# Name: prccd, dtype: float64
# TAK
# count    9806.000000
# mean     3198.747635
# std      2480.726600
# min        23.200000
# 25%        41.200000
# 50%      3786.500000
# 75%      5080.000000
# max      8350.000000
# Name: prccd, dtype: float64
# TKOMY
# count    6.677000e+03
# mean     2.418794e+05
# std      5.663679e+05
# min      8.480000e+02
# 25%      1.440000e+03
# 50%      3.440000e+03
# 75%      5.269000e+03
# max      2.400000e+06
# Name: prccd, dtype: float64
# TM
# count    12980.000000
# mean      3631.724403
# std       2809.920545
# min         40.950000
# 25%         66.700000
# 50%       3510.000000
# 75%       6270.000000
# max       9949.000000
# Name: prccd, dtype: float64
# SFTBY
# count     12166.000000
# mean       4423.316330
# std       10768.338275
# min           5.630000
# 25%          38.360000
# 50%        1918.000000
# 75%        5729.500000
# max      182000.000000
# Name: prccd, dtype: float64
# CJPRY
# count    6.001000e+03
# mean     5.010642e+05
# std      4.165052e+05
# min      6.400000e+03
# 25%      2.046000e+04
# 50%      6.230000e+05
# 75%      7.800000e+05
# max      1.480000e+06
# Name: prccd, dtype: float64
# MFG
# count    8.417000e+03
# mean     1.244658e+05
# std      2.549059e+05
# min      2.150000e+00
# 25%      2.990000e+00
# 50%      1.663000e+02
# 75%      1.529500e+03
# max      1.020000e+06
# Name: prccd, dtype: float64

# %%
df_jp.loc[df_jp["tic"] == "SMFG"].min()
# Out:
# iid                                   01W
# datadate                         19950104
# conm         SUMITOMO MITSUI FINANCIAL GR
# ajexdi                                0.1
# cshoc                           5709424.0
# cshtrd                             3572.0
# prccd                               335.0
# prchd                               350.0
# prcld                               310.0
# prcstd                                5.0
# divd                                  3.0
# anncdate                       19950206.0
# trfd                             1.031697
# isin                         JP3890350006
# sedol                             6563024
# tic                                  SMFG
# log_prccd                        5.814131
# dtype: object

# %%
last_occurrence_date = {}
for tic in jp_tics:
    lastdate = df_jp.loc[df_jp["tic"] == tic]["datadate"].values[-1]
    last_occurrence_date.update({tic: lastdate})
print(last_occurrence_date)
### NOTE: all companies seem to have time series data available up to the latest possible date, which is good

# %%
#plt.plot(df_jp[(df_jp.conm=="SUMITOMO MITSUI FINANCIAL GR")]["datadate"], 
#         df_jp[(df_jp.conm=="SUMITOMO MITSUI FINANCIAL GR")]["prccd"])
plot_historical_ts(df=df_jp,
                   subplot_rows=2, subplot_cols=1,
                   x_cols_list=["datadate"]*2,
                   y_cols_list=["prccd", "log_prccd"],
                   datecol="datadate",
                   titles_list=["SUMITOMO MITSUI FINANCIAL GR Stock Price 1995-2021", 
                                "SUMITOMO MITSUI FINANCIAL GR Log Stock Price 1995-2021"],
                   x_labels_list=["Date", "Date"],
                   y_labels_list=["Stock Price", "Log Stock Price"],
                   comp_names_list=["SUMITOMO MITSUI FINANCIAL GR"], 
                   daterange_str="1995-2021", 
                   comp_name_column="conm", figsize=(17,9), 
                   legend_location="right", legend_location_exact=(0.01,-0.04,1.1, 1.1),
                   legend_borderpad=2., legend_borderaxespad=0., 
                   legend_fontsize=16., label_fontsize=15.,
                   title_fontsize=18., title_pad=18., space_between_plots=0.5, 
                   label_pad=10., 
                   ylim_left_list=[-1000000,
                                   df_jp["log_prccd"][df_jp["conm"].isin(["SUMITOMO MITSUI FINANCIAL GR"])].min()], 
                   ylim_right_list=[df_jp["prccd"][df_jp["conm"].isin(["SUMITOMO MITSUI FINANCIAL GR"])].max(),
                                    df_jp["log_prccd"][df_jp["conm"].isin(["SUMITOMO MITSUI FINANCIAL GR"])].max()])

# %%
plt.plot(df_jp[(df_jp.conm=="KDDI CORP")]["datadate"], 
         df_jp[(df_jp.conm=="KDDI CORP")]["prccd"])
# Out:
# 26
# array(['ALPMY', 'DSNKY', 'DKILY', 'FANUY', 'HTHIY', 'HMC', 'HOCPF',
#        'ITOCY', 'KAOCF', 'KDDIY', 'KYCCF', 'MBC', 'MITSY', 'MRAAY',
#        'NJDCY', 'NTDOY', 'NTTYY', 'SHECY', 'SONY', 'SMFG', 'TAK', 'TKOMY',
#        'TM', 'SFTBY', 'CJPRY', 'MFG'], dtype=object)

# %%
# vizual sanity check for each stock
jp_tics = df_jp["tic"].unique()
jp_tics.sort()
plot_historical_ts(df=df_jp,
                   subplot_rows=2, subplot_cols=1,
                   x_cols_list=["datadate"]*2,
                   y_cols_list=["prccd", "log_prccd"],
                   datecol="datadate",
                   titles_list=["Historical Prices Japan Stocks 1995-2021", 
                                "Historical Log Prices Japan Stocks 1995-2021"],
                   x_labels_list=["Date", "Date"],
                   y_labels_list=["Stock Price", "Log Stock Price"],
                   comp_names_list=jp_tics, 
                   daterange_str="1995-2021", 
                   comp_name_column="tic", figsize=(17,9), 
                   legend_location="right", legend_location_exact=(0.01,-0.04,1.1, 1.1),
                   legend_borderpad=2., legend_borderaxespad=0., 
                   legend_fontsize=16., label_fontsize=15.,
                   title_fontsize=18., title_pad=18., space_between_plots=0.5, 
                   label_pad=10., 
                   ylim_left_list=[df_jp["prccd"][df_jp["tic"].isin(jp_tics)].min(),
                                   df_jp["log_prccd"][df_jp["tic"].isin(jp_tics)].min()], 
                   ylim_right_list=[df_jp["prccd"][df_jp["tic"].isin(jp_tics)].max(),
                                    df_jp["log_prccd"][df_jp["tic"].isin(jp_tics)].max()])
# Out:
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py:70: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
# we see above that some stock still look weird as if they have "damaged" data or 0 stock price at certain times.
# need to check

#check for 0 stock price
for tic in df_jp["tic"].unique():
    subset = df_jp.loc[df_jp["tic"]==tic]
    print(tic)
    print(subset["prccd"].describe())
# Out:
# ALPMY
# count    12233.000000
# mean      1723.547477
# std       1814.206188
# min          7.610000
# 25%         27.130000
# 50%       1523.000000
# 75%       3210.000000
# max       6598.000000
# Name: prccd, dtype: float64
# DSNKY
# count     6680.000000
# mean      2712.200674
# std       1385.047323
# min       1178.000000
# 25%       1835.875000
# 50%       2390.000000
# 75%       3110.000000
# max      10085.000000
# Name: prccd, dtype: float64
# DKILY
# count     6722.000000
# mean      5223.504061
# std       5089.423736
# min        149.100000
# 25%       2043.250000
# 50%       2915.000000
# 75%       7319.750000
# max      24320.000000
# Name: prccd, dtype: float64
# FANUY
# count     6904.000000
# mean     11591.071603
# std       6956.297055
# min        146.500000
# 25%       5900.000000
# 50%      10115.000000
# 75%      17280.000000
# max      33450.000000
# Name: prccd, dtype: float64
# HTHIY
# count    6679.000000
# mean     1083.991915
# std      1030.872749
# min       231.000000
# 25%       607.500000
# 50%       775.000000
# 75%      1020.000000
# max      6154.000000
# Name: prccd, dtype: float64
# HMC
# count    6684.000000
# mean     3710.010697
# std      1102.373473
# min      1150.000000
# 25%      2961.500000
# 50%      3597.000000
# 75%      4357.750000
# max      8400.000000
# Name: prccd, dtype: float64
# HOCPF
# count     8602.000000
# mean      4302.764817
# std       3631.454061
# min         20.113000
# 25%       1681.250000
# 50%       3810.000000
# 75%       6650.000000
# max      15240.000000
# Name: prccd, dtype: float64
# ITOCY
# count    6683.000000
# mean     1009.326201
# std       679.266052
# min       168.000000
# 25%       495.000000
# 50%       800.000000
# 75%      1323.000000
# max      3616.000000
# Name: prccd, dtype: float64
# KAOCF
# count    6683.000000
# mean     3675.204100
# std      2182.997274
# min       960.000000
# 25%      2193.500000
# 50%      2885.000000
# 75%      4901.500000
# max      9290.000000
# Name: prccd, dtype: float64
# KDDIY
# count    1.246100e+04
# mean     2.185329e+05
# std      3.155979e+05
# min      1.828000e+01
# 25%      2.913500e+03
# 50%      4.844000e+03
# 75%      4.930000e+05
# max      1.530000e+06
# Name: prccd, dtype: float64
# KYCCF
# count     6683.000000
# mean     32181.583870
# std      17599.397488
# min       8550.000000
# 25%      19430.000000
# 50%      25210.000000
# 75%      43645.000000
# max      83790.000000
# Name: prccd, dtype: float64
# MBC
# count    6684.000000
# mean     1821.814482
# std       785.639487
# min       581.000000
# 25%      1060.000000
# 50%      1847.000000
# 75%      2414.500000
# max      3930.000000
# Name: prccd, dtype: float64
# MITSY
# count    6683.000000
# mean     1284.715248
# std       491.989630
# min       521.000000
# 25%       841.000000
# 50%      1261.000000
# 75%      1630.000000
# max      3080.000000
# Name: prccd, dtype: float64
# MRAAY
# count     6685.000000
# mean      8170.442064
# std       4664.738064
# min          0.600000
# 25%       4620.000000
# 50%       6350.000000
# 75%       9800.000000
# max      25000.000000
# Name: prccd, dtype: float64
# NJDCY
# count     9612.000000
# mean      6242.807506
# std       5292.023126
# min          9.538000
# 25%         27.800000
# 50%       6690.000000
# 75%       9210.000000
# max      29790.000000
# Name: prccd, dtype: float64
# NTDOY
# count     6676.000000
# mean     22314.975285
# std      14905.261754
# min       4590.000000
# 25%      11400.000000
# 50%      17370.000000
# 75%      27943.750000
# max      71900.000000
# Name: prccd, dtype: float64
# NTTYY
# count    7.627000e+03
# mean     3.412314e+05
# std      4.298575e+05
# min      3.257000e+02
# 25%      3.795000e+03
# 50%      5.619000e+03
# 75%      5.690000e+05
# max      1.900000e+06
# Name: prccd, dtype: float64
# SHECY
# count     6685.000000
# mean      5998.153628
# std       3308.443526
# min       1450.000000
# 25%       4030.000000
# 50%       4980.000000
# 75%       7310.000000
# max      19710.000000
# Name: prccd, dtype: float64
# SONY
# count    16372.000000
# mean      2323.709861
# std       3652.765631
# min          7.380000
# 25%         34.990000
# 50%         50.450000
# 75%       3940.000000
# max      32600.000000
# Name: prccd, dtype: float64
# SMFG
# count    6.675000e+03
# mean     1.820434e+05
# std      3.658143e+05
# min      3.350000e+02
# 25%      1.890000e+03
# 50%      3.598000e+03
# 75%      4.945000e+03
# max      1.380000e+06
# Name: prccd, dtype: float64
# TAK
# count    9806.000000
# mean     3198.747635
# std      2480.726600
# min        23.200000
# 25%        41.200000
# 50%      3786.500000
# 75%      5080.000000
# max      8350.000000
# Name: prccd, dtype: float64
# TKOMY
# count    6.677000e+03
# mean     2.418794e+05
# std      5.663679e+05
# min      8.480000e+02
# 25%      1.440000e+03
# 50%      3.440000e+03
# 75%      5.269000e+03
# max      2.400000e+06
# Name: prccd, dtype: float64
# TM
# count    12980.000000
# mean      3631.724403
# std       2809.920545
# min         40.950000
# 25%         66.700000
# 50%       3510.000000
# 75%       6270.000000
# max       9949.000000
# Name: prccd, dtype: float64
# SFTBY
# count     12166.000000
# mean       4423.316330
# std       10768.338275
# min           5.630000
# 25%          38.360000
# 50%        1918.000000
# 75%        5729.500000
# max      182000.000000
# Name: prccd, dtype: float64
# CJPRY
# count    6.001000e+03
# mean     5.010642e+05
# std      4.165052e+05
# min      6.400000e+03
# 25%      2.046000e+04
# 50%      6.230000e+05
# 75%      7.800000e+05
# max      1.480000e+06
# Name: prccd, dtype: float64
# MFG
# count    8.417000e+03
# mean     1.244658e+05
# std      2.549059e+05
# min      2.150000e+00
# 25%      2.990000e+00
# 50%      1.663000e+02
# 75%      1.529500e+03
# max      1.020000e+06
# Name: prccd, dtype: float64

# %%
df_jp.loc[df_jp["tic"] == "SMFG"].min()
# Out:
# iid                                   01W
# datadate                         19950104
# conm         SUMITOMO MITSUI FINANCIAL GR
# ajexdi                                0.1
# cshoc                           5709424.0
# cshtrd                             3572.0
# prccd                               335.0
# prchd                               350.0
# prcld                               310.0
# prcstd                                5.0
# divd                                  3.0
# anncdate                       19950206.0
# trfd                             1.031697
# isin                         JP3890350006
# sedol                             6563024
# tic                                  SMFG
# log_prccd                        5.814131
# dtype: object

# %%
last_occurrence_date = {}
for tic in jp_tics:
    lastdate = df_jp.loc[df_jp["tic"] == tic]["datadate"].values[-1]
    last_occurrence_date.update({tic: lastdate})
print(last_occurrence_date)
### NOTE: all companies seem to have time series data available up to the latest possible date, which is good
# Out:
# {'ALPMY': 20210611, 'CJPRY': 20210611, 'DKILY': 20210611, 'DSNKY': 20210611, 'FANUY': 20210611, 'HMC': 20210611, 'HOCPF': 20210611, 'HTHIY': 20210611, 'ITOCY': 20210611, 'KAOCF': 20210611, 'KDDIY': 20210611, 'KYCCF': 20210611, 'MBC': 20210611, 'MFG': 20210611, 'MITSY': 20210611, 'MRAAY': 20210611, 'MUFG': 20210611, 'NJDCY': 20210611, 'NTDOY': 20210611, 'NTTYY': 20210611, 'RCRRF': 20210611, 'SFTBY': 20210611, 'SHECY': 20210611, 'SMFG': 20210611, 'SONY': 20210611, 'SVNDY': 20210611, 'TAK': 20210611, 'TKOMY': 20210611, 'TM': 20210611}

# %%
#plt.plot(df_jp[(df_jp.conm=="SUMITOMO MITSUI FINANCIAL GR")]["datadate"], 
#         df_jp[(df_jp.conm=="SUMITOMO MITSUI FINANCIAL GR")]["prccd"])
plot_historical_ts(df=df_jp,
                   subplot_rows=2, subplot_cols=1,
                   x_cols_list=["datadate"]*2,
                   y_cols_list=["prccd", "log_prccd"],
                   datecol="datadate",
                   titles_list=["SUMITOMO MITSUI FINANCIAL GR Stock Price 1995-2021", 
                                "SUMITOMO MITSUI FINANCIAL GR Log Stock Price 1995-2021"],
                   x_labels_list=["Date", "Date"],
                   y_labels_list=["Stock Price", "Log Stock Price"],
                   comp_names_list=["SUMITOMO MITSUI FINANCIAL GR"], 
                   daterange_str="1995-2021", 
                   comp_name_column="conm", figsize=(17,9), 
                   legend_location="right", legend_location_exact=(0.01,-0.04,1.1, 1.1),
                   legend_borderpad=2., legend_borderaxespad=0., 
                   legend_fontsize=16., label_fontsize=15.,
                   title_fontsize=18., title_pad=18., space_between_plots=0.5, 
                   label_pad=10., 
                   ylim_left_list=[-1000000,
                                   df_jp["log_prccd"][df_jp["conm"].isin(["SUMITOMO MITSUI FINANCIAL GR"])].min()], 
                   ylim_right_list=[df_jp["prccd"][df_jp["conm"].isin(["SUMITOMO MITSUI FINANCIAL GR"])].max(),
                                    df_jp["log_prccd"][df_jp["conm"].isin(["SUMITOMO MITSUI FINANCIAL GR"])].max()])
# Out:
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py:70: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.

# %%
plt.plot(df_jp[(df_jp.conm=="KDDI CORP")]["datadate"], 
         df_jp[(df_jp.conm=="KDDI CORP")]["prccd"])

# %%
k
# this is the price chart of KDDI corp. we see that the price variates beteen 13'400 on one day and 1'440'000
# on the other day. This is a very large fluctuation, even for yen
# are prices in yen?
# Out:
#             prccd  datadate
# gvkey
# 201584    13400.0  20000103
# 201584  1440000.0  20000104
# 201584    13400.0  20000104
# 201584  1420000.0  20000105
# 201584    13000.0  20000105
# ...           ...       ...
# 201584    10800.0  20000531
# 201584  1100000.0  20000601
# 201584    10600.0  20000601
# 201584  1080000.0  20000602
# 201584    10350.0  20000602
#
# [214 rows x 2 columns]
