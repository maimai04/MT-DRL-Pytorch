# %%
import logging
from preprocessing.preprocessors import *
from config.config import *
from config.config import settings, crisis_settings, paths, env_params, dataprep_settings
from setup_functions import *
from model.models_ import *
from model.models_pipeline import *

import os

# %%
# see: https://wrds-www.wharton.upenn.edu/
# https://wrds-www.wharton.upenn.edu/pages/support/programming-wrds/programming-python/querying-wrds-data-python/

def fetch_remote_dataset(database: str = dataprep_settings.DATABASE
                         ) -> None:
    # username: baca0426
    # pw: AmalgamiaWonder123_ 
    if database == "WhartonDB":
        db = wrds.Connection()
    return db
db = fetch_remote_dataset()
# Out:
# Enter your WRDS username [Andy]:baca0426
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
libraries = db.list_libraries()
libraries

# %%
db.list_tables("djones")

# %%
# See all column headers in a table
col_headers = db.describe_table(library='djones', table='djdaily')
col_headers.head()

# %%
# query data
sql_query = """
SELECT date,
       djc,
       djct,
       dji,
       djit
FROM djones.djdaily
"""
# WHERE cik IN ('0000000003', '0000000003', '0000000003', '0000000003', '0000000003')

# %%
data_query = db.raw_sql(sql_query)
data_query

# %%
db.describe_table(library="djones", table="djdaily")

# %%
"""
run only PPO
everything else c.p.

additional changes from BCAP:
- added comments
- added variable which_run, to save subsequent runs in corresponding folders.
- 
"""
seeds_list = [223445, 80923, 11112, 23, 5]

results_dir, trained_dir = create_dirs(mode="run_dir")
logsave_path = os.path.join(results_dir, "_LOGGINGS")
os.makedirs(logsave_path)

# call function to write all configurations / related parameters into the config_log.txt file in folder _LOGGING
# so later this file can be consulted to uniquely identify each run and its configurations
config_logging_to_txt(results_dir, trained_dir, seeds_list=seeds_list, logsave_path=logsave_path)
logging.basicConfig(filename=os.path.join(logsave_path, "run_log"),
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    # asctime = time, msecs, name = name of who runned it (?), levelname (e.g. DEBUG, INFO => verbosity), message
                    datefmt='%H:%M:%S',
                    level=logging.INFO)
# Out:
# ['aha',
#  'aha_sample',
#  'ahasamp',
#  'audit',
#  'auditsmp',
#  'bank',
#  'blab',
#  'block',
#  'block_all_new',
#  'boardex',
#  'boardex_trial',
#  'boardsmp',
#  'bvd',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'centris',
#  'ciq',
#  'ciq_capstrct',
#  'ciq_common',
#  'ciq_keydev',
#  'ciq_pplintel',
#  'ciqsamp',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'ciqsamp_ratings',
#  'ciqsamp_transactions',
#  'ciqsamp_transcripts',
#  'cisdm',
#  'cisdmsmp',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'compa',
#  'compb',
#  'compbd',
#  'compdcur',
#  'compg',
#  'compgd',
#  'comph',
#  'compm',
#  'compmcur',
#  'compnad',
#  'compsamp',
#  'compsamp_snapshot',
#  'compseg',
#  'compsegd',
#  'compsnap',
#  'comscore',
#  'contrib',
#  'contrib_ceo_turnover',
#  'contrib_char_returns',
#  'contrib_general',
#  'contrib_general_new',
#  'contrib_intangible_value',
#  'contrib_kpss',
#  'contrib_liva',
#  'crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_a_stock_new',
#  'crsp_a_treasuries',
#  'crsp_q_indexhist',
#  'crspa',
#  'crspm',
#  'crspq',
#  'crspsamp',
#  'csmar',
#  'dealscan',
#  'djones',
#  'dmef',
#  'doe',
#  'emdb',
#  'etfg',
#  'etfgsamp',
#  'eureka',
#  'eurekahedge_sample',
#  'eursamp',
#  'evts',
#  'execcomp',
#  'factsamp_revere',
#  'factset',
#  'ff',
#  'fisd',
#  'fisdsamp',
#  'fjc',
#  'fjc_linking',
#  'fjc_litigation',
#  'frb',
#  'fssamp',
#  'ftse',
#  'ftsesamp',
#  'ginsight',
#  'gmi',
#  'govpx',
#  'govpxsmp',
#  'gsi',
#  'hbase_sample',
#  'hbsamp',
#  'hfr',
#  'hfrsamp',
#  'hfrsamp_hfrdb',
#  'ibes',
#  'ibescorp',
#  'ibeskpi',
#  'ifgr',
#  'ifgrsamp',
#  'ims',
#  'ims_obp_trial',
#  'imssamp',
#  'infogroupsamp_business',
#  'infogroupsamp_residential',
#  'iri',
#  'iss',
#  'issm',
#  'kld',
#  'kld_histall',
#  'ktmine',
#  'ktmine_patents_samp',
#  'ktsamp',
#  'levin',
#  'lspd',
#  'lspdsamp',
#  'lvnsamp',
#  'macrofin',
#  'macrofin_comm_trade',
#  'macrofin_comm_trade_new',
#  'markit',
#  'mfl',
#  'midas',
#  'mrktsamp',
#  'mrktsamp_cds',
#  'mrktsamp_cdx',
#  'mrktsamp_msf',
#  'msfanly',
#  'msfinst',
#  'msrb',
#  'msrbsamp',
#  'nastraq',
#  'omtrial',
#  'optionm',
#  'optionm_all_new',
#  'optionmsamp_europe',
#  'optionmsamp_us',
#  'otc',
#  'otc_endofday',
#  'pacap',
#  'phlx',
#  'ppublica',
#  'ppubsamp',
#  'ppubsamp_d4d',
#  'ppubsamp_d4d_new',
#  'preqin',
#  'preqsamp',
#  'preqsamp_all_new',
#  'public',
#  'pwt',
#  'ravenpack_trial',
#  'rent',
#  'reprisk',
#  'reprisk_common',
#  'reprisk_pm',
#  'reprisk_sample',
#  'repsamp',
#  'revere',
#  'risk',
#  'risksamp',
#  'rpa',
#  'rpna',
#  'rpnasamp',
#  'sdc',
#  'sdcsamp',
#  'secsamp',
#  'secsamp_all_new',
#  'snapsamp',
#  'snl',
#  'snlsamp',
#  'snlsamp_fig',
#  'sprat',
#  'sustain',
#  'sustsamp',
#  'taq',
#  'taqm_2013',
#  'taqm_2014',
#  'taqm_2015',
#  'taqm_2016',
#  'taqm_2017',
#  'taqm_2018',
#  'taqm_2019',
#  'taqm_2020',
#  'taqm_2021',
#  'taqmsamp',
#  'taqmsec',
#  'taqsamp',
#  'tass',
#  'tfn',
#  'totalq',
#  'totalq_all_new',
#  'toyo',
#  'toyosamp',
#  'tr_13f',
#  'tr_dealscan',
#  'tr_ds',
#  'tr_ibes',
#  'tr_ibes_guidance',
#  'tr_ibes_new',
#  'tr_insiders',
#  'trace',
#  'trace_enhanced',
#  'trace_standard',
#  'trdssamp',
#  'trdstrm',
#  'tresg',
#  'trown',
#  'trsamp',
#  'trsamp_ds_eq',
#  'trsamp_dscom',
#  'trsamp_dsecon',
#  'trsamp_dsfut',
#  'trsdcgs',
#  'trws',
#  'twoiq',
#  'twoiq_samp',
#  'twoiqsmp',
#  'wcai',
#  'wqa',
#  'wrds_lib_internal',
#  'wrdsapps',
#  'wrdsapps_backtest_basic',
#  'wrdsapps_backtest_basic_new',
#  'wrdsapps_backtest_plus',
#  'wrdsapps_backtest_plus_new',
#  'wrdsapps_eushort',
#  'wrdsapps_eushort_new',
#  'wrdsapps_evtstudy_lr',
#  'wrdsapps_evtstudy_lr_new',
#  'wrdsapps_finratio',
#  'wrdsapps_finratio_ccm',
#  'wrdsapps_finratio_ibes',
#  'wrdsapps_finratio_ibes_ccm',
#  'wrdsapps_finratio_new',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_ibes_new',
#  'wrdsapps_patents',
#  'wrdsapps_patents_new',
#  'wrdsapps_windices',
#  'wrdsrpts',
#  'wrdsrpts_rep_usage',
#  'wrdssec',
#  'wrdssec_midas',
#  'wrdssec_midas_new',
#  'zacks',
#  'zacksamp']

# %%
db.list_tables("djones")
# Out:
# ['djdaily', 'djmonthly']

# %%
# See all column headers in a table
col_headers = db.describe_table(library='djones', table='djdaily')
col_headers.head()
# Out:
# Approximately 28003 rows in djones.djdaily.
#    name  nullable              type
# 0  date      True              DATE
# 1   djc      True  DOUBLE_PRECISION
# 2  djct      True  DOUBLE_PRECISION
# 3   dji      True  DOUBLE_PRECISION
# 4  djit      True  DOUBLE_PRECISION

# %%
# query data
sql_query = """
SELECT date,
       djc,
       djct,
       dji,
       djit
FROM djones.djdaily
"""
# WHERE cik IN ('0000000003', '0000000003', '0000000003', '0000000003', '0000000003')

# %%
data_query = db.raw_sql(sql_query)
data_query
# Out:
#              date      djc     djct       dji      djit
# 0      1896-05-26      NaN      NaN     40.94       NaN
# 1      1896-05-27      NaN      NaN     40.58       NaN
# 2      1896-05-28      NaN      NaN     40.20       NaN
# 3      1896-05-29      NaN      NaN     40.63       NaN
# 4      1896-06-01      NaN      NaN     40.60       NaN
# ...           ...      ...      ...       ...       ...
# 28068  2008-06-13  4384.54  7478.90  12307.35  20618.70
# 28069  2008-06-16  4379.57  7470.43  12269.08  20554.60
# 28070  2008-06-17  4347.56  7415.81  12160.30  20372.36
# 28071  2008-06-18  4325.74  7378.61  12029.06  20152.48
# 28072  2008-06-19  4386.49  7482.97  12063.09  20213.73
#
# [28073 rows x 5 columns]

# %%
db.describe_table(library="djones", table="djdaily")
# Out:
# Approximately 28003 rows in djones.djdaily.
#    name  nullable              type
# 0  date      True              DATE
# 1   djc      True  DOUBLE_PRECISION
# 2  djct      True  DOUBLE_PRECISION
# 3   dji      True  DOUBLE_PRECISION
# 4  djit      True  DOUBLE_PRECISION
# 5   djt      True  DOUBLE_PRECISION
# 6  djtt      True  DOUBLE_PRECISION
# 7   dju      True  DOUBLE_PRECISION
# 8  djut      True  DOUBLE_PRECISION

# %%
"""
run only PPO
everything else c.p.

additional changes from BCAP:
- added comments
- added variable which_run, to save subsequent runs in corresponding folders.
- 
"""
seeds_list = [223445, 80923, 11112, 23, 5]

results_dir, trained_dir = create_dirs(mode="run_dir")
logsave_path = os.path.join(results_dir, "_LOGGINGS")
os.makedirs(logsave_path)

# call function to write all configurations / related parameters into the config_log.txt file in folder _LOGGING
# so later this file can be consulted to uniquely identify each run and its configurations
config_logging_to_txt(results_dir, trained_dir, seeds_list=seeds_list, logsave_path=logsave_path)
logging.basicConfig(filename=os.path.join(logsave_path, "run_log"),
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    # asctime = time, msecs, name = name of who runned it (?), levelname (e.g. DEBUG, INFO => verbosity), message
                    datefmt='%H:%M:%S',
                    level=logging.INFO)

# %%
#### LOAD / LOAD & PREPROCESS DATA
####-------------------------------
# call function to get the preprocessed data / get the raw data and preprocess it, depending on params in config.py
data = data_handling(  # simplify, make more readable and move mostly into config file
    preprocess_anew=dataprep_settings.PREPROCESS_ANEW,
    preprocessed_data_file=None,  # paths.PREPROCESSED_DATA_FILE,
    save_path=paths.PREPROCESSED_DATA_PATH,
    # BASE PARAMS FOR LOADING THE RAW DATA SET for preprocessing pipeline - with load_dataset()
    raw_data_file=paths.RAW_DATA_FILE,
    col_subset=dataprep_settings.RAW_DF_COLS_SUBSET,
    date_subset="datadate",
    date_subset_startdate=settings.STARTDATE_TRAIN,
    # PASSING NAMES OF OPTIONAL FUNCTIONS TO BE USED in preprocessing pipeline
    calculate_price_volume_func="calculate_price_volume_WhartonData",
    add_technical_indicator_func="add_technical_indicator_with_StockStats",
    # add_other_features_func=None,  # "add_other_features"
    add_other_features_func="add_other_features",
    add_ANN_features_func=None,
    add_crisis_measure_func="add_crisis_measure",
    # PASSING PARAMETERS FOR EACH OPTIONAL FUNCTION
    calculate_price_volume_func_params={"new_cols_subset": dataprep_settings.NEW_COLS_SUBSET,
                                        "target_subset": None},
    add_technical_indicator_func_params={"technical_indicators_list": dataprep_settings.TECH_INDICATORS},
    add_other_features_func_params={"feature": "returns_volatility",
                                    "window_days": 7},
    add_ANN_features_func_params={},
    add_crisis_measure_func_params={"crisis_measure": crisis_settings.CRISIS_MEASURE},
)

# %%
# SETUP
# -------
# get parameters about dataframe shape
stock_dim, n_features, unique_trade_dates_validation = \
    get_data_params(final_df=data,
                    asset_name_column=dataprep_settings.ASSET_NAME_COLUMN,
                    feature_cols=dataprep_settings.ALL_USED_COLUMNS,
                    date_column=dataprep_settings.DATE_COLUMN,
                    base_cols=dataprep_settings.BASE_DF_COLS,
                    startdate_validation=settings.STARTDATE_VALIDATION,
                    enddate_validation=settings.ENDDATE_VALIDATION,
                    )
# save unique trade dates to csv
utd = pd.DataFrame(unique_trade_dates_validation)
utd.to_csv(os.path.join(results_dir, "unique_trade_dates_validation.csv"), index=False)
del utd

# Shape = [Current Balance]+[prices 1-30]+[owned shares 1-30] +[macd 1-30]+ [rsi 1-30] + [cci 1-30] + [adx 1-30]
shape_observation_space = n_features * stock_dim + stock_dim + 1  # +1 for cash

# %%
logging.info("number of validation trading dates: "+str(len(unique_trade_dates_validation)))
logging.info("shape observation space: "+str(shape_observation_space))
logging.info(f"number of columns (all features used): {str(n_features)}, number of stocks: {str(stock_dim)}")
logging.info(f"unique_trade_dates_validation[0] = {unique_trade_dates_validation[0]}")

# %%
run_count = 0
for seed in seeds_list:
    run_count += 1
    settings.SEED_PPO = seed
    logging.info("###########################################################")
    logging.info(f"### RUN {str(run_count)} --- AGENT SEED: {str(settings.SEED_PPO)}.###")
    logging.info("###########################################################")

    #### SETUP
    ####------------------------------
    # call function create_dirs() specified above to create the directory for saving results and the trained model
    # based on the paths/parameters specified in the config.py file
    results_subdir, trained_subdir = create_dirs(mode="seed_dir", results_dir=results_dir, trained_dir=trained_dir)

    #### RUN MODEL SETUP
    ####-------------------------------
    # call run_model function to run the actual DRL algorithm
    run_model_pipeline(data=data,
                       results_dir=results_subdir,
                       trained_dir=trained_subdir,
                       stock_dim=stock_dim,
                       n_features=n_features,
                       shape_observation_space=shape_observation_space,
                       unique_trade_dates_validation=unique_trade_dates_validation)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 229, in run_model
#     logging.info("current episode        : ", current_episode_number)
# Message: 'current episode        : '
# Arguments: (1,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 230, in run_model
#     logging.info("iteration (time step)  : ", i - settings.REBALANCE_WINDOW - settings.VALIDATION_WINDOW + 1)
# Message: 'iteration (time step)  : '
# Arguments: (1,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 344, in run_model
#     trained_dir=trained_dir)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 97, in train_PPO
#     logging.info("Training time (PPO): ", (end_ppo - start_ppo) / 60, " minutes")
# Message: 'Training time (PPO): '
# Arguments: (7.034956999619802, ' minutes')
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 349, in run_model
#     test_obs=obs_val)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 172, in DRL_validation
#     logging.info("Validation time: ", (end - start) / 60, " minutes")
# Message: 'Validation time: '
# Arguments: (0.003342004617055257, ' minutes')
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 351, in run_model
#     logging.info("PPO Sharpe Ratio: ", sharpe_ppo)
# Message: 'PPO Sharpe Ratio: '
# Arguments: (0.12127749319895961,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 370, in run_model
#     shape_observation_space=shape_observation_space)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 163, in DRL_trading
#     logging.info("Trading time: ", (end - start) / 60, " minutes")
# Message: 'Trading time: '
# Arguments: (0.0038628339767456054, ' minutes')
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 229, in run_model
#     logging.info("current episode        : ", current_episode_number)
# Message: 'current episode        : '
# Arguments: (2,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
# ...
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 229, in run_model
#     logging.info("current episode        : ", current_episode_number)
# Message: 'current episode        : '
# Arguments: (6,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\logging\__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 541, in run_forever
#     self._run_once()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\base_events.py", line 1786, in _run_once
#     handle._run()
#   File "C:\Users\Andy\AppData\Local\Programs\Python\Python37\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-1662b0dfd0ac>", line 24, in <module>
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py", line 283, in run_model_pipeline
#     unique_trade_dates_validation=unique_trade_dates_validation)
#   File "C:\Users\Andy\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py", line 230, in run_model
#     logging.info("iteration (time step)  : ", i - settings.REBALANCE_WINDOW - settings.VALIDATION_WINDOW + 1)
# Message: 'iteration (time step)  : '
# Arguments: (316,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-1662b0dfd0ac> in <module>
#      22                        n_features=n_features,
#      23                        shape_observation_space=shape_observation_space,
# ---> 24                        unique_trade_dates_validation=unique_trade_dates_validation)
#
# ~\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\setup_functions.py in run_model_pipeline(data, results_dir, trained_dir, stock_dim, n_features, shape_observation_space, unique_trade_dates_validation)
#     281                   n_features=n_features,
#     282                   shape_observation_space=shape_observation_space,
# --> 283                   unique_trade_dates_validation=unique_trade_dates_validation)
#     284     elif settings.STRATEGY_MODE == "ensemble":
#     285         logging.info(f"(RUN) STRATEGY_MODE: {settings.STRATEGY_MODE}.")
#
# ~\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py in run_model(df, results_dir, trained_dir, stock_dim, n_features, shape_observation_space, unique_trade_dates_validation)
#     342                                         f"train_ending_{train_ending}",
#     343                               timesteps=ppo_params.TRAINING_TIMESTEPS,
# --> 344                               trained_dir=trained_dir)
#     345         logging.info(f"======PPO Validation from: {validation_beginning} to {validation_ending}, (i={i}).======")
#     346         DRL_validation(model=model_ppo,
#
# ~\PycharmProjects\finrlpaper2\MT-DRL-Pytorch\model\models.py in train_PPO(env_train, save_name, trained_dir, timesteps)
#      92                  )
#      93     # model = PPO2('MlpPolicy', env_train, ent_coef = 0.005)
# ---> 94     model.learn(total_timesteps=timesteps)
#      95     end_ppo = time.time()
#      96     model.save(f"{trained_dir}/{save_name}")
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     287             tb_log_name=tb_log_name,
#     288             eval_log_path=eval_log_path,
# --> 289             reset_num_timesteps=reset_num_timesteps,
#     290         )
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     225         while self.num_timesteps < total_timesteps:
#     226
# --> 227             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     228
#     229             if continue_training is False:
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     157                 # Convert to pytorch tensor
#     158                 obs_tensor = th.as_tensor(self._last_obs).to(self.device)
# --> 159                 actions, values, log_probs = self.policy.forward(obs_tensor)
#     160             actions = actions.cpu().numpy()
#     161
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\policies.py in forward(self, obs, deterministic)
#     535         # Evaluate the values for the given observations
#     536         values = self.value_net(latent_vf)
# --> 537         distribution = self._get_action_dist_from_latent(latent_pi, latent_sde=latent_sde)
#     538         actions = distribution.get_actions(deterministic=deterministic)
#     539         log_prob = distribution.log_prob(actions)
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\policies.py in _get_action_dist_from_latent(self, latent_pi, latent_sde)
#     570
#     571         if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 572             return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     573         elif isinstance(self.action_dist, CategoricalDistribution):
#     574             # Here mean_actions are the logits before the softmax
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\stable_baselines3\common\distributions.py in proba_distribution(self, mean_actions, log_std)
#     150         """
#     151         action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 152         self.distribution = Normal(mean_actions, action_std)
#     153         return self
#     154
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\torch\distributions\normal.py in __init__(self, loc, scale, validate_args)
#      48         else:
#      49             batch_shape = self.loc.size()
# ---> 50         super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#      51
#      52     def expand(self, batch_shape, _instance=None):
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\torch\distributions\distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      50                 if param not in self.__dict__ and isinstance(getattr(type(self), param), lazy_property):
#      51                     continue  # skip checking lazily-constructed args
# ---> 52                 if not constraint.check(getattr(self, param)).all():
#      53                     raise ValueError("The parameter {} has invalid values".format(param))
#      54         super(Distribution, self).__init__()
#
# c:\users\andy\pycharmprojects\finrlpaper2\mt-drl-pytorch\finrlpapervenv\lib\site-packages\torch\distributions\constraints.py in check(self, value)
#     299     """
#     300     def check(self, value):
# --> 301         return value == value  # False for NANs.
#     302
#     303
#
# KeyboardInterrupt:
